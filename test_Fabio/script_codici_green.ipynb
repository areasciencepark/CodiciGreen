# %% [markdown]
# # Make a full list of Green codes

# %% [markdown]
# Autori: Fabio Morea, Leyla Vesnic, Andrea Bincoletto
# Data: 20 giugno 2022
# Versione 1.0
# GitHub: https://github.com/areasciencepark/CodiciGreen

# %% [markdown]
# ## load libraries

# %%
import pandas as pd 
import re

# %% [markdown]
# ## Load data

# %%
# reading data and selecting only the column we are interested in
raw_data = pd.read_excel("../2IPCGreenInventoryList_2022WIPO.xlsx", dtype=str)
raw_data = raw_data[[ "IPC"]]
raw_data.dropna(inplace=True)
raw_data.head(5)
# Out:
#                      IPC
# 2   C10L 5/00, 5/40-5/48
# 3             C10B 53/02
# 4        C10L 5/40, 9/00
# 5  C10L 1/00, 1/02, 1/14
# 6        C10L 1/02, 1/19

# %%
codes = pd.read_excel("../IPC WIPO unione.xlsx", dtype=str)
codes = list(codes["ipc_class_symbol"])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-12-159d4a963337> in <module>
# ----> 1 codes = pd.read_excel("../IPC WIPO unione.xlsx", dtype=str)
#       2 codes = list(codes["ipc_class_symbol"])
#
# c:\Users\morea\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\Users\morea\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# c:\Users\morea\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1069                 ext = "xls"
#    1070             else:
# -> 1071                 ext = inspect_excel_format(
#    1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#
# c:\Users\morea\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(path, content, storage_options)
#     947     assert content_or_path is not None
#     948
# --> 949     with get_handle(
#     950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#
# c:\Users\morea\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# PermissionError: [Errno 13] Permission denied: '../IPC WIPO unione.xlsx'

# %% [markdown]
# ## scan eaach row of the dataframe to generate a list of results
#
# "," is the separator for lists of codes
# "-" is the separator for sequences
# and add individual results in a codes_list[]

# %%
codes_list = []
i=0

for index, row in raw_data.iterrows():
    parts = row['IPC'].split(" ")
    first_part  = parts[0]
    for p in range(0,len(parts)):
        parts[p] = re.sub("\xa0"," ",parts[p]) 
        if parts[p][-1]==",": 
            print("issue with final comma", parts[p])
            parts[p] = parts[p][:-1]
            print("solved issue with final comma", parts[p])
            
    print("PARTS: ",parts, len(parts))
    
    if len(parts) == 1:
        print(i,j, "this is a short code ", parts[0])
        i+=1
        codes_list.append(parts[0])
    else:
        other_parts=[]
        for p in range(0,len(parts)):
            other_parts = other_parts + parts[p].split(",")
                
        print("PROCESSING the parts ",other_parts,len(other_parts))
        for j in range(0,len(other_parts)):
            print("FOR loop ", j, other_parts[j])
            this_part = re.sub(" ", "",other_parts[j]) #remove whitespaces
            this_part = re.sub('"',"",this_part) # 



            full_code = first_part + this_part
            
            if (len(this_part))==0:
                print("this part is EMPTY!", full_code)
            elif not("-" in this_part):
                i+=1
                codes_list.append(full_code)
                print(i,j,"Adding a single code ", full_code)
            
            else:#sequenza
                sequence_start = first_part + this_part.split("-")[0]
                sequence_end   = first_part + this_part.split("-")[1]
                print(i,j, "** This is a sequence from ", sequence_start, " to " , sequence_end)
                # scan the full list of codes and add everything from sequence_start to sequence_end
                get_also_next_code = False
                found_any_code = False
                for cod in codes:
                    if (cod == sequence_start): 

                        print("ADDING the sequence start",cod)
                        i+=1
                        found_any_code = True
                        codes_list.append(cod)
                        get_also_next_code = True
                    elif (cod == sequence_end): 
                        print("ADDING end of the sequence end",cod)
                        i+=1
                        found_any_code = True
                        codes_list.append(cod)
                        get_also_next_code = False
                        break #don't need to search in the rest of the list
                    elif (get_also_next_code==True):
                        print("ADDING A PART OF the sequence",cod)
                        i+=1
                        found_any_code = True
                        codes_list.append(cod)
                if found_any_code == False: print("WARNING no codes found for the given sequence")
print("Done :-D")

codes_list = sorted(list(set(codes_list)))
print(len(codes_list), " codes found")
# Out:
# PARTS:  ['C10L', '5/00, 5/40-5/48'] 2
# PROCESSING the parts  ['C10L', '5/00', ' 5/40-5/48'] 3
# FOR loop  0 C10L
# 1 0 Adding a single code  C10LC10L
# FOR loop  1 5/00
# 2 1 Adding a single code  C10L5/00
# FOR loop  2  5/40-5/48
# 2 2 ** This is a sequence from  C10L5/40  to  C10L5/48
# ADDING the sequence start C10L5/40
# ADDING A PART OF the sequence C10L5/42
# ADDING A PART OF the sequence C10L5/44
# ADDING A PART OF the sequence C10L5/46
# ADDING end of the sequence end C10L5/48
# PARTS:  ['C10B', '53/02'] 2
# PROCESSING the parts  ['C10B', '53/02'] 2
# FOR loop  0 C10B
# 8 0 Adding a single code  C10BC10B
# FOR loop  1 53/02
# 9 1 Adding a single code  C10B53/02
# PARTS:  ['C10L', '5/40, 9/00'] 2
# PROCESSING the parts  ['C10L', '5/40', ' 9/00'] 3
# FOR loop  0 C10L
# 10 0 Adding a single code  C10LC10L
# FOR loop  1 5/40
# 11 1 Adding a single code  C10L5/40
# FOR loop  2  9/00
# 12 2 Adding a single code  C10L9/00
# PARTS:  ['C10L', '1/00, 1/02, 1/14'] 2
# PROCESSING the parts  ['C10L', '1/00', ' 1/02', ' 1/14'] 4
# FOR loop  0 C10L
# 13 0 Adding a single code  C10LC10L
# FOR loop  1 1/00
# 14 1 Adding a single code  C10L1/00
# FOR loop  2  1/02
# 15 2 Adding a single code  C10L1/02
# FOR loop  3  1/14
# 16 3 Adding a single code  C10L1/14
# PARTS:  ['C10L', '1/02, 1/19'] 2
# PROCESSING the parts  ['C10L', '1/02', ' 1/19'] 3
# FOR loop  0 C10L
# 17 0 Adding a single code  C10LC10L
# FOR loop  1 1/02
# 18 1 Adding a single code  C10L1/02
# FOR loop  2  1/19
# 19 2 Adding a single code  C10L1/19
# PARTS:  ['C07C', '67/00, 69/00'] 2
# PROCESSING the parts  ['C07C', '67/00', ' 69/00'] 3
# FOR loop  0 C07C
# 20 0 Adding a single code  C07CC07C
# FOR loop  1 67/00
# 21 1 Adding a single code  C07C67/00
# FOR loop  2  69/00
# 22 2 Adding a single code  C07C69/00
# PARTS:  ['C10G'] 1
# 22 2 this is a short code  C10G
# PARTS:  ['C10L', '1/02, 1/19'] 2
# PROCESSING the parts  ['C10L', '1/02', ' 1/19'] 3
# FOR loop  0 C10L
# 24 0 Adding a single code  C10LC10L
# FOR loop  1 1/02
# 25 1 Adding a single code  C10L1/02
# FOR loop  2  1/19
# 26 2 Adding a single code  C10L1/19
# PARTS:  ['C11C', '3/10'] 2
# PROCESSING the parts  ['C11C', '3/10'] 2
# FOR loop  0 C11C
# 27 0 Adding a single code  C11CC11C
# FOR loop  1 3/10
# 28 1 Adding a single code  C11C3/10
# PARTS:  ['C12P', '7/649'] 2
# PROCESSING the parts  ['C12P', '7/649'] 2
# FOR loop  0 C12P
# 29 0 Adding a single code  C12PC12P
# FOR loop  1 7/649
# 30 1 Adding a single code  C12P7/649
# PARTS:  ['C10L', '1/02, 1/182'] 2
# PROCESSING the parts  ['C10L', '1/02', ' 1/182'] 3
# FOR loop  0 C10L
# 31 0 Adding a single code  C10LC10L
# FOR loop  1 1/02
# 32 1 Adding a single code  C10L1/02
# FOR loop  2  1/182
# 33 2 Adding a single code  C10L1/182
# PARTS:  ['C12N', '9/24'] 2
# PROCESSING the parts  ['C12N', '9/24'] 2
# FOR loop  0 C12N
# 34 0 Adding a single code  C12NC12N
# FOR loop  1 9/24
# 35 1 Adding a single code  C12N9/24
# PARTS:  ['C12P', '7/06-7/14'] 2
# PROCESSING the parts  ['C12P', '7/06-7/14'] 2
# FOR loop  0 C12P
# 36 0 Adding a single code  C12PC12P
# FOR loop  1 7/06-7/14
# 36 1 ** This is a sequence from  C12P7/06  to  C12P7/14
# ADDING the sequence start C12P7/06
# ADDING A PART OF the sequence C12P7/08
# ADDING A PART OF the sequence C12P7/10
# ADDING A PART OF the sequence C12P7/12
# ADDING end of the sequence end C12P7/14
# PARTS:  ['C02F', '3/28, 11/04'] 2
# PROCESSING the parts  ['C02F', '3/28', ' 11/04'] 3
# FOR loop  0 C02F
# 42 0 Adding a single code  C02FC02F
# FOR loop  1 3/28
# 43 1 Adding a single code  C02F3/28
# FOR loop  2  11/04
# 44 2 Adding a single code  C02F11/04
# PARTS:  ['C10L', '3/00'] 2
# PROCESSING the parts  ['C10L', '3/00'] 2
# FOR loop  0 C10L
# 45 0 Adding a single code  C10LC10L
# FOR loop  1 3/00
# 46 1 Adding a single code  C10L3/00
# PARTS:  ['C12M', '1/107'] 2
# PROCESSING the parts  ['C12M', '1/107'] 2
# FOR loop  0 C12M
# 47 0 Adding a single code  C12MC12M
# FOR loop  1 1/107
# 48 1 Adding a single code  C12M1/107
# PARTS:  ['C12P', '5/02'] 2
# PROCESSING the parts  ['C12P', '5/02'] 2
# FOR loop  0 C12P
# 49 0 Adding a single code  C12PC12P
# FOR loop  1 5/02
# 50 1 Adding a single code  C12P5/02
# PARTS:  ['C12N', '1/13, 1/15, 1/21, 5/10, 15/00'] 2
# PROCESSING the parts  ['C12N', '1/13', ' 1/15', ' 1/21', ' 5/10', ' 15/00'] 6
# FOR loop  0 C12N
# 51 0 Adding a single code  C12NC12N
# FOR loop  1 1/13
# 52 1 Adding a single code  C12N1/13
# FOR loop  2  1/15
# 53 2 Adding a single code  C12N1/15
# FOR loop  3  1/21
# 54 3 Adding a single code  C12N1/21
# FOR loop  4  5/10
# 55 4 Adding a single code  C12N5/10
# FOR loop  5  15/00
# 56 5 Adding a single code  C12N15/00
# PARTS:  ['A01H'] 1
# 56 5 this is a short code  A01H
# PARTS:  ['C10L', '3/00'] 2
# PROCESSING the parts  ['C10L', '3/00'] 2
# FOR loop  0 C10L
# 58 0 Adding a single code  C10LC10L
# FOR loop  1 3/00
# 59 1 Adding a single code  C10L3/00
# PARTS:  ['F02C', '3/28'] 2
# PROCESSING the parts  ['F02C', '3/28'] 2
# FOR loop  0 F02C
# 60 0 Adding a single code  F02CF02C
# FOR loop  1 3/28
# 61 1 Adding a single code  F02C3/28
# PARTS:  ['H01M', '4/86-4/98, 8/00-8/24, 12/00-12/08'] 2
# PROCESSING the parts  ['H01M', '4/86-4/98', ' 8/00-8/24', ' 12/00-12/08'] 4
# FOR loop  0 H01M
# 62 0 Adding a single code  H01MH01M
# FOR loop  1 4/86-4/98
# 62 1 ** This is a sequence from  H01M4/86  to  H01M4/98
# ADDING the sequence start H01M4/86
# ADDING A PART OF the sequence H01M4/88
# ADDING A PART OF the sequence H01M4/90
# ADDING A PART OF the sequence H01M4/92
# ADDING A PART OF the sequence H01M4/94
# ADDING A PART OF the sequence H01M4/96
# ADDING end of the sequence end H01M4/98
# FOR loop  2  8/00-8/24
# 69 2 ** This is a sequence from  H01M8/00  to  H01M8/24
# ADDING the sequence start H01M8/00
# ADDING A PART OF the sequence H01M8/008
# ADDING A PART OF the sequence H01M8/02
# ADDING A PART OF the sequence H01M8/0202
# ADDING A PART OF the sequence H01M8/0204
# ADDING A PART OF the sequence H01M8/0206
# ADDING A PART OF the sequence H01M8/0208
# ADDING A PART OF the sequence H01M8/021
# ADDING A PART OF the sequence H01M8/0213
# ADDING A PART OF the sequence H01M8/0215
# ADDING A PART OF the sequence H01M8/0217
# ADDING A PART OF the sequence H01M8/0221
# ADDING A PART OF the sequence H01M8/0223
# ADDING A PART OF the sequence H01M8/0226
# ADDING A PART OF the sequence H01M8/0228
# ADDING A PART OF the sequence H01M8/023
# ADDING A PART OF the sequence H01M8/0232
# ADDING A PART OF the sequence H01M8/0234
# ADDING A PART OF the sequence H01M8/0236
# ADDING A PART OF the sequence H01M8/0239
# ADDING A PART OF the sequence H01M8/0241
# ADDING A PART OF the sequence H01M8/0243
# ADDING A PART OF the sequence H01M8/0245
# ADDING A PART OF the sequence H01M8/0247
# ADDING A PART OF the sequence H01M8/025
# ADDING A PART OF the sequence H01M8/0252
# ADDING A PART OF the sequence H01M8/0254
# ADDING A PART OF the sequence H01M8/0256
# ADDING A PART OF the sequence H01M8/0258
# ADDING A PART OF the sequence H01M8/026
# ADDING A PART OF the sequence H01M8/0263
# ADDING A PART OF the sequence H01M8/0265
# ADDING A PART OF the sequence H01M8/0267
# ADDING A PART OF the sequence H01M8/0271
# ADDING A PART OF the sequence H01M8/0273
# ADDING A PART OF the sequence H01M8/0276
# ADDING A PART OF the sequence H01M8/028
# ADDING A PART OF the sequence H01M8/0282
# ADDING A PART OF the sequence H01M8/0284
# ADDING A PART OF the sequence H01M8/0286
# ADDING A PART OF the sequence H01M8/0289
# ADDING A PART OF the sequence H01M8/0293
# ADDING A PART OF the sequence H01M8/0295
# ADDING A PART OF the sequence H01M8/0297
# ADDING A PART OF the sequence H01M8/04
# ADDING A PART OF the sequence H01M8/04007
# ADDING A PART OF the sequence H01M8/04014
# ADDING A PART OF the sequence H01M8/04029
# ADDING A PART OF the sequence H01M8/04044
# ADDING A PART OF the sequence H01M8/04082
# ADDING A PART OF the sequence H01M8/04089
# ADDING A PART OF the sequence H01M8/04111
# ADDING A PART OF the sequence H01M8/04119
# ADDING A PART OF the sequence H01M8/04186
# ADDING A PART OF the sequence H01M8/04223
# ADDING A PART OF the sequence H01M8/04225
# ADDING A PART OF the sequence H01M8/04228
# ADDING A PART OF the sequence H01M8/04276
# ADDING A PART OF the sequence H01M8/04291
# ADDING A PART OF the sequence H01M8/04298
# ADDING A PART OF the sequence H01M8/043
# ADDING A PART OF the sequence H01M8/04302
# ADDING A PART OF the sequence H01M8/04303
# ADDING A PART OF the sequence H01M8/04313
# ADDING A PART OF the sequence H01M8/0432
# ADDING A PART OF the sequence H01M8/0438
# ADDING A PART OF the sequence H01M8/0444
# ADDING A PART OF the sequence H01M8/04492
# ADDING A PART OF the sequence H01M8/04537
# ADDING A PART OF the sequence H01M8/04664
# ADDING A PART OF the sequence H01M8/04694
# ADDING A PART OF the sequence H01M8/04701
# ADDING A PART OF the sequence H01M8/04746
# ADDING A PART OF the sequence H01M8/04791
# ADDING A PART OF the sequence H01M8/04828
# ADDING A PART OF the sequence H01M8/04858
# ADDING A PART OF the sequence H01M8/04955
# ADDING A PART OF the sequence H01M8/04992
# ADDING A PART OF the sequence H01M8/06
# ADDING A PART OF the sequence H01M8/0606
# ADDING A PART OF the sequence H01M8/0612
# ADDING A PART OF the sequence H01M8/0637
# ADDING A PART OF the sequence H01M8/065
# ADDING A PART OF the sequence H01M8/0656
# ADDING A PART OF the sequence H01M8/0662
# ADDING A PART OF the sequence H01M8/0668
# ADDING A PART OF the sequence H01M8/08
# ADDING A PART OF the sequence H01M8/083
# ADDING A PART OF the sequence H01M8/086
# ADDING A PART OF the sequence H01M8/10
# ADDING A PART OF the sequence H01M8/1004
# ADDING A PART OF the sequence H01M8/1006
# ADDING A PART OF the sequence H01M8/1007
# ADDING A PART OF the sequence H01M8/1009
# ADDING A PART OF the sequence H01M8/1011
# ADDING A PART OF the sequence H01M8/1016
# ADDING A PART OF the sequence H01M8/1018
# ADDING A PART OF the sequence H01M8/102
# ADDING A PART OF the sequence H01M8/1023
# ADDING A PART OF the sequence H01M8/1025
# ADDING A PART OF the sequence H01M8/1027
# ADDING A PART OF the sequence H01M8/103
# ADDING A PART OF the sequence H01M8/1032
# ADDING A PART OF the sequence H01M8/1034
# ADDING A PART OF the sequence H01M8/1037
# ADDING A PART OF the sequence H01M8/1039
# ADDING A PART OF the sequence H01M8/1041
# ADDING A PART OF the sequence H01M8/1044
# ADDING A PART OF the sequence H01M8/1046
# ADDING A PART OF the sequence H01M8/1048
# ADDING A PART OF the sequence H01M8/1051
# ADDING A PART OF the sequence H01M8/1053
# ADDING A PART OF the sequence H01M8/1058
# ADDING A PART OF the sequence H01M8/106
# ADDING A PART OF the sequence H01M8/1062
# ADDING A PART OF the sequence H01M8/1065
# ADDING A PART OF the sequence H01M8/1067
# ADDING A PART OF the sequence H01M8/1069
# ADDING A PART OF the sequence H01M8/1072
# ADDING A PART OF the sequence H01M8/1081
# ADDING A PART OF the sequence H01M8/1086
# ADDING A PART OF the sequence H01M8/1088
# ADDING A PART OF the sequence H01M8/1097
# ADDING A PART OF the sequence H01M8/12
# ADDING A PART OF the sequence H01M8/1213
# ADDING A PART OF the sequence H01M8/122
# ADDING A PART OF the sequence H01M8/1226
# ADDING A PART OF the sequence H01M8/1231
# ADDING A PART OF the sequence H01M8/1233
# ADDING A PART OF the sequence H01M8/124
# ADDING A PART OF the sequence H01M8/1246
# ADDING A PART OF the sequence H01M8/1253
# ADDING A PART OF the sequence H01M8/126
# ADDING A PART OF the sequence H01M8/1286
# ADDING A PART OF the sequence H01M8/14
# ADDING A PART OF the sequence H01M8/16
# ADDING A PART OF the sequence H01M8/18
# ADDING A PART OF the sequence H01M8/20
# ADDING A PART OF the sequence H01M8/22
# ADDING end of the sequence end H01M8/24
# FOR loop  3  12/00-12/08
# 209 3 ** This is a sequence from  H01M12/00  to  H01M12/08
# ADDING the sequence start H01M12/00
# ADDING A PART OF the sequence H01M12/02
# ADDING A PART OF the sequence H01M12/04
# ADDING A PART OF the sequence H01M12/06
# ADDING end of the sequence end H01M12/08
# PARTS:  ['H01M', '4/86-4/98'] 2
# PROCESSING the parts  ['H01M', '4/86-4/98'] 2
# FOR loop  0 H01M
# 215 0 Adding a single code  H01MH01M
# FOR loop  1 4/86-4/98
# 215 1 ** This is a sequence from  H01M4/86  to  H01M4/98
# ADDING the sequence start H01M4/86
# ADDING A PART OF the sequence H01M4/88
# ADDING A PART OF the sequence H01M4/90
# ADDING A PART OF the sequence H01M4/92
# ADDING A PART OF the sequence H01M4/94
# ADDING A PART OF the sequence H01M4/96
# ADDING end of the sequence end H01M4/98
# PARTS:  ['H01M', '4/86-4/98'] 2
# PROCESSING the parts  ['H01M', '4/86-4/98'] 2
# FOR loop  0 H01M
# 223 0 Adding a single code  H01MH01M
# FOR loop  1 4/86-4/98
# 223 1 ** This is a sequence from  H01M4/86  to  H01M4/98
# ADDING the sequence start H01M4/86
# ADDING A PART OF the sequence H01M4/88
# ADDING A PART OF the sequence H01M4/90
# ADDING A PART OF the sequence H01M4/92
# ADDING A PART OF the sequence H01M4/94
# ADDING A PART OF the sequence H01M4/96
# ADDING end of the sequence end H01M4/98
# issue with final comma 8/00-8/24,
# solved issue with final comma 8/00-8/24
# PARTS:  ['H01M', '8/00-8/24', '50/00-50/171'] 3
# PROCESSING the parts  ['H01M', '8/00-8/24', '50/00-50/171'] 3
# FOR loop  0 H01M
# 231 0 Adding a single code  H01MH01M
# FOR loop  1 8/00-8/24
# 231 1 ** This is a sequence from  H01M8/00  to  H01M8/24
# ADDING the sequence start H01M8/00
# ADDING A PART OF the sequence H01M8/008
# ADDING A PART OF the sequence H01M8/02
# ADDING A PART OF the sequence H01M8/0202
# ADDING A PART OF the sequence H01M8/0204
# ADDING A PART OF the sequence H01M8/0206
# ADDING A PART OF the sequence H01M8/0208
# ADDING A PART OF the sequence H01M8/021
# ADDING A PART OF the sequence H01M8/0213
# ADDING A PART OF the sequence H01M8/0215
# ADDING A PART OF the sequence H01M8/0217
# ADDING A PART OF the sequence H01M8/0221
# ADDING A PART OF the sequence H01M8/0223
# ADDING A PART OF the sequence H01M8/0226
# ADDING A PART OF the sequence H01M8/0228
# ADDING A PART OF the sequence H01M8/023
# ADDING A PART OF the sequence H01M8/0232
# ADDING A PART OF the sequence H01M8/0234
# ADDING A PART OF the sequence H01M8/0236
# ADDING A PART OF the sequence H01M8/0239
# ADDING A PART OF the sequence H01M8/0241
# ADDING A PART OF the sequence H01M8/0243
# ADDING A PART OF the sequence H01M8/0245
# ADDING A PART OF the sequence H01M8/0247
# ADDING A PART OF the sequence H01M8/025
# ADDING A PART OF the sequence H01M8/0252
# ADDING A PART OF the sequence H01M8/0254
# ADDING A PART OF the sequence H01M8/0256
# ADDING A PART OF the sequence H01M8/0258
# ADDING A PART OF the sequence H01M8/026
# ADDING A PART OF the sequence H01M8/0263
# ADDING A PART OF the sequence H01M8/0265
# ADDING A PART OF the sequence H01M8/0267
# ADDING A PART OF the sequence H01M8/0271
# ADDING A PART OF the sequence H01M8/0273
# ADDING A PART OF the sequence H01M8/0276
# ADDING A PART OF the sequence H01M8/028
# ADDING A PART OF the sequence H01M8/0282
# ADDING A PART OF the sequence H01M8/0284
# ADDING A PART OF the sequence H01M8/0286
# ADDING A PART OF the sequence H01M8/0289
# ADDING A PART OF the sequence H01M8/0293
# ADDING A PART OF the sequence H01M8/0295
# ADDING A PART OF the sequence H01M8/0297
# ADDING A PART OF the sequence H01M8/04
# ADDING A PART OF the sequence H01M8/04007
# ADDING A PART OF the sequence H01M8/04014
# ADDING A PART OF the sequence H01M8/04029
# ADDING A PART OF the sequence H01M8/04044
# ADDING A PART OF the sequence H01M8/04082
# ADDING A PART OF the sequence H01M8/04089
# ADDING A PART OF the sequence H01M8/04111
# ADDING A PART OF the sequence H01M8/04119
# ADDING A PART OF the sequence H01M8/04186
# ADDING A PART OF the sequence H01M8/04223
# ADDING A PART OF the sequence H01M8/04225
# ADDING A PART OF the sequence H01M8/04228
# ADDING A PART OF the sequence H01M8/04276
# ADDING A PART OF the sequence H01M8/04291
# ADDING A PART OF the sequence H01M8/04298
# ADDING A PART OF the sequence H01M8/043
# ADDING A PART OF the sequence H01M8/04302
# ADDING A PART OF the sequence H01M8/04303
# ADDING A PART OF the sequence H01M8/04313
# ADDING A PART OF the sequence H01M8/0432
# ADDING A PART OF the sequence H01M8/0438
# ADDING A PART OF the sequence H01M8/0444
# ADDING A PART OF the sequence H01M8/04492
# ADDING A PART OF the sequence H01M8/04537
# ADDING A PART OF the sequence H01M8/04664
# ADDING A PART OF the sequence H01M8/04694
# ADDING A PART OF the sequence H01M8/04701
# ADDING A PART OF the sequence H01M8/04746
# ADDING A PART OF the sequence H01M8/04791
# ADDING A PART OF the sequence H01M8/04828
# ADDING A PART OF the sequence H01M8/04858
# ADDING A PART OF the sequence H01M8/04955
# ADDING A PART OF the sequence H01M8/04992
# ADDING A PART OF the sequence H01M8/06
# ADDING A PART OF the sequence H01M8/0606
# ADDING A PART OF the sequence H01M8/0612
# ADDING A PART OF the sequence H01M8/0637
# ADDING A PART OF the sequence H01M8/065
# ADDING A PART OF the sequence H01M8/0656
# ADDING A PART OF the sequence H01M8/0662
# ADDING A PART OF the sequence H01M8/0668
# ADDING A PART OF the sequence H01M8/08
# ADDING A PART OF the sequence H01M8/083
# ADDING A PART OF the sequence H01M8/086
# ADDING A PART OF the sequence H01M8/10
# ADDING A PART OF the sequence H01M8/1004
# ADDING A PART OF the sequence H01M8/1006
# ADDING A PART OF the sequence H01M8/1007
# ADDING A PART OF the sequence H01M8/1009
# ADDING A PART OF the sequence H01M8/1011
# ADDING A PART OF the sequence H01M8/1016
# ADDING A PART OF the sequence H01M8/1018
# ADDING A PART OF the sequence H01M8/102
# ADDING A PART OF the sequence H01M8/1023
# ADDING A PART OF the sequence H01M8/1025
# ADDING A PART OF the sequence H01M8/1027
# ADDING A PART OF the sequence H01M8/103
# ADDING A PART OF the sequence H01M8/1032
# ADDING A PART OF the sequence H01M8/1034
# ADDING A PART OF the sequence H01M8/1037
# ADDING A PART OF the sequence H01M8/1039
# ADDING A PART OF the sequence H01M8/1041
# ADDING A PART OF the sequence H01M8/1044
# ADDING A PART OF the sequence H01M8/1046
# ADDING A PART OF the sequence H01M8/1048
# ADDING A PART OF the sequence H01M8/1051
# ADDING A PART OF the sequence H01M8/1053
# ADDING A PART OF the sequence H01M8/1058
# ADDING A PART OF the sequence H01M8/106
# ADDING A PART OF the sequence H01M8/1062
# ADDING A PART OF the sequence H01M8/1065
# ADDING A PART OF the sequence H01M8/1067
# ADDING A PART OF the sequence H01M8/1069
# ADDING A PART OF the sequence H01M8/1072
# ADDING A PART OF the sequence H01M8/1081
# ADDING A PART OF the sequence H01M8/1086
# ADDING A PART OF the sequence H01M8/1088
# ADDING A PART OF the sequence H01M8/1097
# ADDING A PART OF the sequence H01M8/12
# ADDING A PART OF the sequence H01M8/1213
# ADDING A PART OF the sequence H01M8/122
# ADDING A PART OF the sequence H01M8/1226
# ADDING A PART OF the sequence H01M8/1231
# ADDING A PART OF the sequence H01M8/1233
# ADDING A PART OF the sequence H01M8/124
# ADDING A PART OF the sequence H01M8/1246
# ADDING A PART OF the sequence H01M8/1253
# ADDING A PART OF the sequence H01M8/126
# ADDING A PART OF the sequence H01M8/1286
# ADDING A PART OF the sequence H01M8/14
# ADDING A PART OF the sequence H01M8/16
# ADDING A PART OF the sequence H01M8/18
# ADDING A PART OF the sequence H01M8/20
# ADDING A PART OF the sequence H01M8/22
# ADDING end of the sequence end H01M8/24
# FOR loop  2 50/00-50/171
# 371 2 ** This is a sequence from  H01M50/00  to  H01M50/171
# ADDING the sequence start H01M50/00
# ADDING A PART OF the sequence H01M50/10
# ADDING A PART OF the sequence H01M50/102
# ADDING A PART OF the sequence H01M50/103
# ADDING A PART OF the sequence H01M50/105
# ADDING A PART OF the sequence H01M50/107
# ADDING A PART OF the sequence H01M50/109
# ADDING A PART OF the sequence H01M50/11
# ADDING A PART OF the sequence H01M50/112
# ADDING A PART OF the sequence H01M50/114
# ADDING A PART OF the sequence H01M50/116
# ADDING A PART OF the sequence H01M50/117
# ADDING A PART OF the sequence H01M50/119
# ADDING A PART OF the sequence H01M50/121
# ADDING A PART OF the sequence H01M50/122
# ADDING A PART OF the sequence H01M50/124
# ADDING A PART OF the sequence H01M50/126
# ADDING A PART OF the sequence H01M50/128
# ADDING A PART OF the sequence H01M50/129
# ADDING A PART OF the sequence H01M50/131
# ADDING A PART OF the sequence H01M50/133
# ADDING A PART OF the sequence H01M50/134
# ADDING A PART OF the sequence H01M50/136
# ADDING A PART OF the sequence H01M50/138
# ADDING A PART OF the sequence H01M50/14
# ADDING A PART OF the sequence H01M50/141
# ADDING A PART OF the sequence H01M50/143
# ADDING A PART OF the sequence H01M50/145
# ADDING A PART OF the sequence H01M50/147
# ADDING A PART OF the sequence H01M50/148
# ADDING A PART OF the sequence H01M50/15
# ADDING A PART OF the sequence H01M50/152
# ADDING A PART OF the sequence H01M50/153
# ADDING A PART OF the sequence H01M50/155
# ADDING A PART OF the sequence H01M50/157
# ADDING A PART OF the sequence H01M50/159
# ADDING A PART OF the sequence H01M50/16
# ADDING A PART OF the sequence H01M50/162
# ADDING A PART OF the sequence H01M50/164
# ADDING A PART OF the sequence H01M50/166
# ADDING A PART OF the sequence H01M50/167
# ADDING A PART OF the sequence H01M50/169
# ADDING end of the sequence end H01M50/171
# PARTS:  ['H01M', '12/00-12/08'] 2
# PROCESSING the parts  ['H01M', '12/00-12/08'] 2
# FOR loop  0 H01M
# 415 0 Adding a single code  H01MH01M
# FOR loop  1 12/00-12/08
# 415 1 ** This is a sequence from  H01M12/00  to  H01M12/08
# ADDING the sequence start H01M12/00
# ADDING A PART OF the sequence H01M12/02
# ADDING A PART OF the sequence H01M12/04
# ADDING A PART OF the sequence H01M12/06
# ADDING end of the sequence end H01M12/08
# PARTS:  ['C10B', '53/00'] 2
# PROCESSING the parts  ['C10B', '53/00'] 2
# FOR loop  0 C10B
# 421 0 Adding a single code  C10BC10B
# FOR loop  1 53/00
# 422 1 Adding a single code  C10B53/00
# PARTS:  ['C10J'] 1
# 422 1 this is a short code  C10J
# PARTS:  ['C10L', '5/00'] 2
# PROCESSING the parts  ['C10L', '5/00'] 2
# FOR loop  0 C10L
# 424 0 Adding a single code  C10LC10L
# FOR loop  1 5/00
# 425 1 Adding a single code  C10L5/00
# PARTS:  ['C10L', '5/42, 5/44'] 2
# PROCESSING the parts  ['C10L', '5/42', ' 5/44'] 3
# FOR loop  0 C10L
# 426 0 Adding a single code  C10LC10L
# FOR loop  1 5/42
# 427 1 Adding a single code  C10L5/42
# FOR loop  2  5/44
# 428 2 Adding a single code  C10L5/44
# PARTS:  ['F23G', '7/00, 7/10'] 2
# PROCESSING the parts  ['F23G', '7/00', ' 7/10'] 3
# FOR loop  0 F23G
# 429 0 Adding a single code  F23GF23G
# FOR loop  1 7/00
# 430 1 Adding a single code  F23G7/00
# FOR loop  2  7/10
# 431 2 Adding a single code  F23G7/10
# PARTS:  ['C10J', '3/02, 3/46'] 2
# PROCESSING the parts  ['C10J', '3/02', ' 3/46'] 3
# FOR loop  0 C10J
# 432 0 Adding a single code  C10JC10J
# FOR loop  1 3/02
# 433 1 Adding a single code  C10J3/02
# FOR loop  2  3/46
# 434 2 Adding a single code  C10J3/46
# PARTS:  ['F23B', '90/00'] 2
# PROCESSING the parts  ['F23B', '90/00'] 2
# FOR loop  0 F23B
# 435 0 Adding a single code  F23BF23B
# FOR loop  1 90/00
# 436 1 Adding a single code  F23B90/00
# PARTS:  ['F23G', '5/027'] 2
# PROCESSING the parts  ['F23G', '5/027'] 2
# FOR loop  0 F23G
# 437 0 Adding a single code  F23GF23G
# FOR loop  1 5/027
# 438 1 Adding a single code  F23G5/027
# PARTS:  ['B09B', '3/00'] 2
# PROCESSING the parts  ['B09B', '3/00'] 2
# FOR loop  0 B09B
# 439 0 Adding a single code  B09BB09B
# FOR loop  1 3/00
# 440 1 Adding a single code  B09B3/00
# PARTS:  ['F23G', '7/00'] 2
# PROCESSING the parts  ['F23G', '7/00'] 2
# FOR loop  0 F23G
# 441 0 Adding a single code  F23GF23G
# FOR loop  1 7/00
# 442 1 Adding a single code  F23G7/00
# PARTS:  ['C10L', '5/48'] 2
# PROCESSING the parts  ['C10L', '5/48'] 2
# FOR loop  0 C10L
# 443 0 Adding a single code  C10LC10L
# FOR loop  1 5/48
# 444 1 Adding a single code  C10L5/48
# PARTS:  ['F23G', '5/00, 7/00'] 2
# PROCESSING the parts  ['F23G', '5/00', ' 7/00'] 3
# FOR loop  0 F23G
# 445 0 Adding a single code  F23GF23G
# FOR loop  1 5/00
# 446 1 Adding a single code  F23G5/00
# FOR loop  2  7/00
# 447 2 Adding a single code  F23G7/00
# PARTS:  ['C21B', '5/06'] 2
# PROCESSING the parts  ['C21B', '5/06'] 2
# FOR loop  0 C21B
# 448 0 Adding a single code  C21BC21B
# FOR loop  1 5/06
# 449 1 Adding a single code  C21B5/06
# PARTS:  ['D21C', '11/00'] 2
# PROCESSING the parts  ['D21C', '11/00'] 2
# FOR loop  0 D21C
# 450 0 Adding a single code  D21CD21C
# FOR loop  1 11/00
# 451 1 Adding a single code  D21C11/00
# PARTS:  ['A62D', '3/02'] 2
# PROCESSING the parts  ['A62D', '3/02'] 2
# FOR loop  0 A62D
# 452 0 Adding a single code  A62DA62D
# FOR loop  1 3/02
# 453 1 Adding a single code  A62D3/02
# PARTS:  ['C02F', '11/04, 11/14'] 2
# PROCESSING the parts  ['C02F', '11/04', ' 11/14'] 3
# FOR loop  0 C02F
# 454 0 Adding a single code  C02FC02F
# FOR loop  1 11/04
# 455 1 Adding a single code  C02F11/04
# FOR loop  2  11/14
# 456 2 Adding a single code  C02F11/14
# PARTS:  ['F23G', '7/00, 7/10'] 2
# PROCESSING the parts  ['F23G', '7/00', ' 7/10'] 3
# FOR loop  0 F23G
# 457 0 Adding a single code  F23GF23G
# FOR loop  1 7/00
# 458 1 Adding a single code  F23G7/00
# FOR loop  2  7/10
# 459 2 Adding a single code  F23G7/10
# PARTS:  ['B09B', '3/00'] 2
# PROCESSING the parts  ['B09B', '3/00'] 2
# FOR loop  0 B09B
# 460 0 Adding a single code  B09BB09B
# FOR loop  1 3/00
# 461 1 Adding a single code  B09B3/00
# PARTS:  ['F23G', '5/00'] 2
# PROCESSING the parts  ['F23G', '5/00'] 2
# FOR loop  0 F23G
# 462 0 Adding a single code  F23GF23G
# FOR loop  1 5/00
# 463 1 Adding a single code  F23G5/00
# PARTS:  ['B09B'] 1
# 463 1 this is a short code  B09B
# PARTS:  ['B01D', '53/02, 53/04, 53/047, 53/14, 53/22, 53/24'] 2
# PROCESSING the parts  ['B01D', '53/02', ' 53/04', ' 53/047', ' 53/14', ' 53/22', ' 53/24'] 7
# FOR loop  0 B01D
# 465 0 Adding a single code  B01DB01D
# FOR loop  1 53/02
# 466 1 Adding a single code  B01D53/02
# FOR loop  2  53/04
# 467 2 Adding a single code  B01D53/04
# FOR loop  3  53/047
# 468 3 Adding a single code  B01D53/047
# FOR loop  4  53/14
# 469 4 Adding a single code  B01D53/14
# FOR loop  5  53/22
# 470 5 Adding a single code  B01D53/22
# FOR loop  6  53/24
# 471 6 Adding a single code  B01D53/24
# PARTS:  ['C10L', '5/46'] 2
# PROCESSING the parts  ['C10L', '5/46'] 2
# FOR loop  0 C10L
# 472 0 Adding a single code  C10LC10L
# FOR loop  1 5/46
# 473 1 Adding a single code  C10L5/46
# PARTS:  ['F23G', '5/00'] 2
# PROCESSING the parts  ['F23G', '5/00'] 2
# FOR loop  0 F23G
# 474 0 Adding a single code  F23GF23G
# FOR loop  1 5/00
# 475 1 Adding a single code  F23G5/00
# PARTS:  ['E02B', '9/00-9/06'] 2
# PROCESSING the parts  ['E02B', '9/00-9/06'] 2
# FOR loop  0 E02B
# 476 0 Adding a single code  E02BE02B
# FOR loop  1 9/00-9/06
# 476 1 ** This is a sequence from  E02B9/00  to  E02B9/06
# ADDING the sequence start E02B9/00
# ADDING A PART OF the sequence E02B9/02
# ADDING A PART OF the sequence E02B9/04
# ADDING end of the sequence end E02B9/06
# PARTS:  ['E02B', '9/08'] 2
# PROCESSING the parts  ['E02B', '9/08'] 2
# FOR loop  0 E02B
# 481 0 Adding a single code  E02BE02B
# FOR loop  1 9/08
# 482 1 Adding a single code  E02B9/08
# PARTS:  ['F03B'] 1
# 482 1 this is a short code  F03B
# PARTS:  ['F03C'] 1
# 483 1 this is a short code  F03C
# PARTS:  ['F03B', '13/12-13/26'] 2
# PROCESSING the parts  ['F03B', '13/12-13/26'] 2
# FOR loop  0 F03B
# 485 0 Adding a single code  F03BF03B
# FOR loop  1 13/12-13/26
# 485 1 ** This is a sequence from  F03B13/12  to  F03B13/26
# ADDING the sequence start F03B13/12
# ADDING A PART OF the sequence F03B13/14
# ADDING A PART OF the sequence F03B13/16
# ADDING A PART OF the sequence F03B13/18
# ADDING A PART OF the sequence F03B13/20
# ADDING A PART OF the sequence F03B13/22
# ADDING A PART OF the sequence F03B13/24
# ADDING end of the sequence end F03B13/26
# PARTS:  ['F03B', '15/00-15/22'] 2
# PROCESSING the parts  ['F03B', '15/00-15/22'] 2
# FOR loop  0 F03B
# 494 0 Adding a single code  F03BF03B
# FOR loop  1 15/00-15/22
# 494 1 ** This is a sequence from  F03B15/00  to  F03B15/22
# ADDING the sequence start F03B15/00
# ADDING A PART OF the sequence F03B15/02
# ADDING A PART OF the sequence F03B15/04
# ADDING A PART OF the sequence F03B15/06
# ADDING A PART OF the sequence F03B15/08
# ADDING A PART OF the sequence F03B15/10
# ADDING A PART OF the sequence F03B15/12
# ADDING A PART OF the sequence F03B15/14
# ADDING A PART OF the sequence F03B15/16
# ADDING A PART OF the sequence F03B15/18
# ADDING A PART OF the sequence F03B15/20
# ADDING end of the sequence end F03B15/22
# PARTS:  ['B63H', '19/02, 19/04'] 2
# PROCESSING the parts  ['B63H', '19/02', ' 19/04'] 3
# FOR loop  0 B63H
# 507 0 Adding a single code  B63HB63H
# FOR loop  1 19/02
# 508 1 Adding a single code  B63H19/02
# FOR loop  2  19/04
# 509 2 Adding a single code  B63H19/04
# PARTS:  ['F03G', '7/05'] 2
# PROCESSING the parts  ['F03G', '7/05'] 2
# FOR loop  0 F03G
# 510 0 Adding a single code  F03GF03G
# FOR loop  1 7/05
# 511 1 Adding a single code  F03G7/05
# PARTS:  ['F03D'] 1
# 511 1 this is a short code  F03D
# PARTS:  ['H02K', '7/18'] 2
# PROCESSING the parts  ['H02K', '7/18'] 2
# FOR loop  0 H02K
# 513 0 Adding a single code  H02KH02K
# FOR loop  1 7/18
# 514 1 Adding a single code  H02K7/18
# PARTS:  ['B63B', '35/00'] 2
# PROCESSING the parts  ['B63B', '35/00'] 2
# FOR loop  0 B63B
# 515 0 Adding a single code  B63BB63B
# FOR loop  1 35/00
# 516 1 Adding a single code  B63B35/00
# PARTS:  ['E04H', '12/00'] 2
# PROCESSING the parts  ['E04H', '12/00'] 2
# FOR loop  0 E04H
# 517 0 Adding a single code  E04HE04H
# FOR loop  1 12/00
# 518 1 Adding a single code  E04H12/00
# PARTS:  ['F03D', '13/00'] 2
# PROCESSING the parts  ['F03D', '13/00'] 2
# FOR loop  0 F03D
# 519 0 Adding a single code  F03DF03D
# FOR loop  1 13/00
# 520 1 Adding a single code  F03D13/00
# PARTS:  ['B60K', '16/00'] 2
# PROCESSING the parts  ['B60K', '16/00'] 2
# FOR loop  0 B60K
# 521 0 Adding a single code  B60KB60K
# FOR loop  1 16/00
# 522 1 Adding a single code  B60K16/00
# PARTS:  ['B60L', '8/00'] 2
# PROCESSING the parts  ['B60L', '8/00'] 2
# FOR loop  0 B60L
# 523 0 Adding a single code  B60LB60L
# FOR loop  1 8/00
# 524 1 Adding a single code  B60L8/00
# PARTS:  ['B63H', '13/00'] 2
# PROCESSING the parts  ['B63H', '13/00'] 2
# FOR loop  0 B63H
# 525 0 Adding a single code  B63HB63H
# FOR loop  1 13/00
# 526 1 Adding a single code  B63H13/00
# PARTS:  ['F24S'] 1
# 526 1 this is a short code  F24S
# PARTS:  ['H02S'] 1
# 527 1 this is a short code  H02S
# PARTS:  ['H01L', '27/142, 31/00-31/078'] 2
# PROCESSING the parts  ['H01L', '27/142', ' 31/00-31/078'] 3
# FOR loop  0 H01L
# 529 0 Adding a single code  H01LH01L
# FOR loop  1 27/142
# 530 1 Adding a single code  H01L27/142
# FOR loop  2  31/00-31/078
# 530 2 ** This is a sequence from  H01L31/00  to  H01L31/078
# ADDING the sequence start H01L31/00
# ADDING A PART OF the sequence H01L31/02
# ADDING A PART OF the sequence H01L31/0203
# ADDING A PART OF the sequence H01L31/0216
# ADDING A PART OF the sequence H01L31/0224
# ADDING A PART OF the sequence H01L31/0232
# ADDING A PART OF the sequence H01L31/0236
# ADDING A PART OF the sequence H01L31/024
# ADDING A PART OF the sequence H01L31/0248
# ADDING A PART OF the sequence H01L31/0256
# ADDING A PART OF the sequence H01L31/0264
# ADDING A PART OF the sequence H01L31/0272
# ADDING A PART OF the sequence H01L31/028
# ADDING A PART OF the sequence H01L31/0288
# ADDING A PART OF the sequence H01L31/0296
# ADDING A PART OF the sequence H01L31/0304
# ADDING A PART OF the sequence H01L31/0312
# ADDING A PART OF the sequence H01L31/032
# ADDING A PART OF the sequence H01L31/0328
# ADDING A PART OF the sequence H01L31/0336
# ADDING A PART OF the sequence H01L31/0352
# ADDING A PART OF the sequence H01L31/036
# ADDING A PART OF the sequence H01L31/0368
# ADDING A PART OF the sequence H01L31/0376
# ADDING A PART OF the sequence H01L31/0384
# ADDING A PART OF the sequence H01L31/0392
# ADDING A PART OF the sequence H01L31/04
# ADDING A PART OF the sequence H01L31/041
# ADDING A PART OF the sequence H01L31/042
# ADDING A PART OF the sequence H01L31/043
# ADDING A PART OF the sequence H01L31/044
# ADDING A PART OF the sequence H01L31/0443
# ADDING A PART OF the sequence H01L31/0445
# ADDING A PART OF the sequence H01L31/045
# ADDING A PART OF the sequence H01L31/046
# ADDING A PART OF the sequence H01L31/0463
# ADDING A PART OF the sequence H01L31/0465
# ADDING A PART OF the sequence H01L31/0468
# ADDING A PART OF the sequence H01L31/047
# ADDING A PART OF the sequence H01L31/0475
# ADDING A PART OF the sequence H01L31/048
# ADDING A PART OF the sequence H01L31/049
# ADDING A PART OF the sequence H01L31/05
# ADDING A PART OF the sequence H01L31/052
# ADDING A PART OF the sequence H01L31/0525
# ADDING A PART OF the sequence H01L31/053
# ADDING A PART OF the sequence H01L31/054
# ADDING A PART OF the sequence H01L31/055
# ADDING A PART OF the sequence H01L31/056
# ADDING A PART OF the sequence H01L31/058
# ADDING A PART OF the sequence H01L31/06
# ADDING A PART OF the sequence H01L31/061
# ADDING A PART OF the sequence H01L31/062
# ADDING A PART OF the sequence H01L31/065
# ADDING A PART OF the sequence H01L31/068
# ADDING A PART OF the sequence H01L31/0687
# ADDING A PART OF the sequence H01L31/0693
# ADDING A PART OF the sequence H01L31/07
# ADDING A PART OF the sequence H01L31/072
# ADDING A PART OF the sequence H01L31/0725
# ADDING A PART OF the sequence H01L31/073
# ADDING A PART OF the sequence H01L31/0735
# ADDING A PART OF the sequence H01L31/074
# ADDING A PART OF the sequence H01L31/0745
# ADDING A PART OF the sequence H01L31/0747
# ADDING A PART OF the sequence H01L31/0749
# ADDING A PART OF the sequence H01L31/075
# ADDING A PART OF the sequence H01L31/076
# ADDING A PART OF the sequence H01L31/077
# ADDING end of the sequence end H01L31/078
# PARTS:  ['H01G', '9/20'] 2
# PROCESSING the parts  ['H01G', '9/20'] 2
# FOR loop  0 H01G
# 601 0 Adding a single code  H01GH01G
# FOR loop  1 9/20
# 602 1 Adding a single code  H01G9/20
# PARTS:  ['H02S', '10/00'] 2
# PROCESSING the parts  ['H02S', '10/00'] 2
# FOR loop  0 H02S
# 603 0 Adding a single code  H02SH02S
# FOR loop  1 10/00
# 604 1 Adding a single code  H02S10/00
# PARTS:  ['H01L', '27/30, 51/42-51/48'] 2
# PROCESSING the parts  ['H01L', '27/30', ' 51/42-51/48'] 3
# FOR loop  0 H01L
# 605 0 Adding a single code  H01LH01L
# FOR loop  1 27/30
# 606 1 Adding a single code  H01L27/30
# FOR loop  2  51/42-51/48
# 606 2 ** This is a sequence from  H01L51/42  to  H01L51/48
# ADDING the sequence start H01L51/42
# ADDING A PART OF the sequence H01L51/44
# ADDING A PART OF the sequence H01L51/46
# ADDING end of the sequence end H01L51/48
# PARTS:  ['H01L', '25/00, 25/03, 25/16, 25/18, 31/042'] 2
# PROCESSING the parts  ['H01L', '25/00', ' 25/03', ' 25/16', ' 25/18', ' 31/042'] 6
# FOR loop  0 H01L
# 611 0 Adding a single code  H01LH01L
# FOR loop  1 25/00
# 612 1 Adding a single code  H01L25/00
# FOR loop  2  25/03
# 613 2 Adding a single code  H01L25/03
# FOR loop  3  25/16
# 614 3 Adding a single code  H01L25/16
# FOR loop  4  25/18
# 615 4 Adding a single code  H01L25/18
# FOR loop  5  31/042
# 616 5 Adding a single code  H01L31/042
# PARTS:  ['C01B', '33/02'] 2
# PROCESSING the parts  ['C01B', '33/02'] 2
# FOR loop  0 C01B
# 617 0 Adding a single code  C01BC01B
# FOR loop  1 33/02
# 618 1 Adding a single code  C01B33/02
# PARTS:  ['C23C', '14/14, 16/24'] 2
# PROCESSING the parts  ['C23C', '14/14', ' 16/24'] 3
# FOR loop  0 C23C
# 619 0 Adding a single code  C23CC23C
# FOR loop  1 14/14
# 620 1 Adding a single code  C23C14/14
# FOR loop  2  16/24
# 621 2 Adding a single code  C23C16/24
# PARTS:  ['C30B', '29/06'] 2
# PROCESSING the parts  ['C30B', '29/06'] 2
# FOR loop  0 C30B
# 622 0 Adding a single code  C30BC30B
# FOR loop  1 29/06
# 623 1 Adding a single code  C30B29/06
# PARTS:  ['G05F', '1/67'] 2
# PROCESSING the parts  ['G05F', '1/67'] 2
# FOR loop  0 G05F
# 624 0 Adding a single code  G05FG05F
# FOR loop  1 1/67
# 625 1 Adding a single code  G05F1/67
# PARTS:  ['F21L', '4/00'] 2
# PROCESSING the parts  ['F21L', '4/00'] 2
# FOR loop  0 F21L
# 626 0 Adding a single code  F21LF21L
# FOR loop  1 4/00
# 627 1 Adding a single code  F21L4/00
# PARTS:  ['F21S', '9/03'] 2
# PROCESSING the parts  ['F21S', '9/03'] 2
# FOR loop  0 F21S
# 628 0 Adding a single code  F21SF21S
# FOR loop  1 9/03
# 629 1 Adding a single code  F21S9/03
# PARTS:  ['H02J', '7/35'] 2
# PROCESSING the parts  ['H02J', '7/35'] 2
# FOR loop  0 H02J
# 630 0 Adding a single code  H02JH02J
# FOR loop  1 7/35
# 631 1 Adding a single code  H02J7/35
# PARTS:  ['H01G', '9/20'] 2
# PROCESSING the parts  ['H01G', '9/20'] 2
# FOR loop  0 H01G
# 632 0 Adding a single code  H01GH01G
# FOR loop  1 9/20
# 633 1 Adding a single code  H01G9/20
# PARTS:  ['H01M', '14/00'] 2
# PROCESSING the parts  ['H01M', '14/00'] 2
# FOR loop  0 H01M
# 634 0 Adding a single code  H01MH01M
# FOR loop  1 14/00
# 635 1 Adding a single code  H01M14/00
# PARTS:  ['F24S'] 1
# 635 1 this is a short code  F24S
# issue with final comma 17/00,
# solved issue with final comma 17/00
# PARTS:  ['F24D', '17/00', '18/00'] 3
# PROCESSING the parts  ['F24D', '17/00', '18/00'] 3
# FOR loop  0 F24D
# 637 0 Adding a single code  F24DF24D
# FOR loop  1 17/00
# 638 1 Adding a single code  F24D17/00
# FOR loop  2 18/00
# 639 2 Adding a single code  F24D18/00
# PARTS:  ['F24D', '3/00, 5/00, 11/00, 19/00'] 2
# PROCESSING the parts  ['F24D', '3/00', ' 5/00', ' 11/00', ' 19/00'] 5
# FOR loop  0 F24D
# 640 0 Adding a single code  F24DF24D
# FOR loop  1 3/00
# 641 1 Adding a single code  F24D3/00
# FOR loop  2  5/00
# 642 2 Adding a single code  F24D5/00
# FOR loop  3  11/00
# 643 3 Adding a single code  F24D11/00
# FOR loop  4  19/00
# 644 4 Adding a single code  F24D19/00
# PARTS:  ['F24S', '90/00'] 2
# PROCESSING the parts  ['F24S', '90/00'] 2
# FOR loop  0 F24S
# 645 0 Adding a single code  F24SF24S
# FOR loop  1 90/00
# 646 1 Adding a single code  F24S90/00
# PARTS:  ['F03D', '1/04, 9/00, 13/20'] 2
# PROCESSING the parts  ['F03D', '1/04', ' 9/00', ' 13/20'] 4
# FOR loop  0 F03D
# 647 0 Adding a single code  F03DF03D
# FOR loop  1 1/04
# 648 1 Adding a single code  F03D1/04
# FOR loop  2  9/00
# 649 2 Adding a single code  F03D9/00
# FOR loop  3  13/20
# 650 3 Adding a single code  F03D13/20
# PARTS:  ['F03G', '6/00'] 2
# PROCESSING the parts  ['F03G', '6/00'] 2
# FOR loop  0 F03G
# 651 0 Adding a single code  F03GF03G
# FOR loop  1 6/00
# 652 1 Adding a single code  F03G6/00
# PARTS:  ['C02F', '1/14'] 2
# PROCESSING the parts  ['C02F', '1/14'] 2
# FOR loop  0 C02F
# 653 0 Adding a single code  C02FC02F
# FOR loop  1 1/14
# 654 1 Adding a single code  C02F1/14
# PARTS:  ['F02C', '1/05'] 2
# PROCESSING the parts  ['F02C', '1/05'] 2
# FOR loop  0 F02C
# 655 0 Adding a single code  F02CF02C
# FOR loop  1 1/05
# 656 1 Adding a single code  F02C1/05
# PARTS:  ['H01L', '31/0525'] 2
# PROCESSING the parts  ['H01L', '31/0525'] 2
# FOR loop  0 H01L
# 657 0 Adding a single code  H01LH01L
# FOR loop  1 31/0525
# 658 1 Adding a single code  H01L31/0525
# PARTS:  ['H02S', '40/44'] 2
# PROCESSING the parts  ['H02S', '40/44'] 2
# FOR loop  0 H02S
# 659 0 Adding a single code  H02SH02S
# FOR loop  1 40/44
# 660 1 Adding a single code  H02S40/44
# PARTS:  ['B60K', '16/00'] 2
# PROCESSING the parts  ['B60K', '16/00'] 2
# FOR loop  0 B60K
# 661 0 Adding a single code  B60KB60K
# FOR loop  1 16/00
# 662 1 Adding a single code  B60K16/00
# PARTS:  ['B60L', '8/00'] 2
# PROCESSING the parts  ['B60L', '8/00'] 2
# FOR loop  0 B60L
# 663 0 Adding a single code  B60LB60L
# FOR loop  1 8/00
# 664 1 Adding a single code  B60L8/00
# PARTS:  ['F03G', '6/00-6/06'] 2
# PROCESSING the parts  ['F03G', '6/00-6/06'] 2
# FOR loop  0 F03G
# 665 0 Adding a single code  F03GF03G
# FOR loop  1 6/00-6/06
# 665 1 ** This is a sequence from  F03G6/00  to  F03G6/06
# ADDING the sequence start F03G6/00
# ADDING A PART OF the sequence F03G6/02
# ADDING A PART OF the sequence F03G6/04
# ADDING end of the sequence end F03G6/06
# PARTS:  ['E04D', '13/00, 13/18'] 2
# PROCESSING the parts  ['E04D', '13/00', ' 13/18'] 3
# FOR loop  0 E04D
# 670 0 Adding a single code  E04DE04D
# FOR loop  1 13/00
# 671 1 Adding a single code  E04D13/00
# FOR loop  2  13/18
# 672 2 Adding a single code  E04D13/18
# PARTS:  ['F22B', '1/00'] 2
# PROCESSING the parts  ['F22B', '1/00'] 2
# FOR loop  0 F22B
# 673 0 Adding a single code  F22BF22B
# FOR loop  1 1/00
# 674 1 Adding a single code  F22B1/00
# PARTS:  ['F24V', '30/00'] 2
# PROCESSING the parts  ['F24V', '30/00'] 2
# FOR loop  0 F24V
# 675 0 Adding a single code  F24VF24V
# FOR loop  1 30/00
# 676 1 Adding a single code  F24V30/00
# PARTS:  ['F25B', '27/00'] 2
# PROCESSING the parts  ['F25B', '27/00'] 2
# FOR loop  0 F25B
# 677 0 Adding a single code  F25BF25B
# FOR loop  1 27/00
# 678 1 Adding a single code  F25B27/00
# PARTS:  ['F26B', '3/00, 3/28'] 2
# PROCESSING the parts  ['F26B', '3/00', ' 3/28'] 3
# FOR loop  0 F26B
# 679 0 Adding a single code  F26BF26B
# FOR loop  1 3/00
# 680 1 Adding a single code  F26B3/00
# FOR loop  2  3/28
# 681 2 Adding a single code  F26B3/28
# PARTS:  ['F24S', '23/00'] 2
# PROCESSING the parts  ['F24S', '23/00'] 2
# FOR loop  0 F24S
# 682 0 Adding a single code  F24SF24S
# FOR loop  1 23/00
# 683 1 Adding a single code  F24S23/00
# PARTS:  ['G02B', '7/183'] 2
# PROCESSING the parts  ['G02B', '7/183'] 2
# FOR loop  0 G02B
# 684 0 Adding a single code  G02BG02B
# FOR loop  1 7/183
# 685 1 Adding a single code  G02B7/183
# PARTS:  ['F24S', '10/10'] 2
# PROCESSING the parts  ['F24S', '10/10'] 2
# FOR loop  0 F24S
# 686 0 Adding a single code  F24SF24S
# FOR loop  1 10/10
# 687 1 Adding a single code  F24S10/10
# PARTS:  ['F24T'] 1
# 687 1 this is a short code  F24T
# PARTS:  ['F01K'] 1
# 688 1 this is a short code  F01K
# PARTS:  ['F24F', '5/00'] 2
# PROCESSING the parts  ['F24F', '5/00'] 2
# FOR loop  0 F24F
# 690 0 Adding a single code  F24FF24F
# FOR loop  1 5/00
# 691 1 Adding a single code  F24F5/00
# PARTS:  ['F24T', '10/00-50/00'] 2
# PROCESSING the parts  ['F24T', '10/00-50/00'] 2
# FOR loop  0 F24T
# 692 0 Adding a single code  F24TF24T
# FOR loop  1 10/00-50/00
# 692 1 ** This is a sequence from  F24T10/00  to  F24T50/00
# ADDING the sequence start F24T10/00
# ADDING A PART OF the sequence F24T10/10
# ADDING A PART OF the sequence F24T10/13
# ADDING A PART OF the sequence F24T10/15
# ADDING A PART OF the sequence F24T10/17
# ADDING A PART OF the sequence F24T10/20
# ADDING A PART OF the sequence F24T10/30
# ADDING A PART OF the sequence F24T10/40
# ADDING end of the sequence end F24T50/00
# PARTS:  ['H02N', '10/00'] 2
# PROCESSING the parts  ['H02N', '10/00'] 2
# FOR loop  0 H02N
# 702 0 Adding a single code  H02NH02N
# FOR loop  1 10/00
# 703 1 Adding a single code  H02N10/00
# PARTS:  ['F25B', '30/06'] 2
# PROCESSING the parts  ['F25B', '30/06'] 2
# FOR loop  0 F25B
# 704 0 Adding a single code  F25BF25B
# FOR loop  1 30/06
# 705 1 Adding a single code  F25B30/06
# PARTS:  ['F03G', '4/00-4/06, 7/04'] 2
# PROCESSING the parts  ['F03G', '4/00-4/06', ' 7/04'] 3
# FOR loop  0 F03G
# 706 0 Adding a single code  F03GF03G
# FOR loop  1 4/00-4/06
# 706 1 ** This is a sequence from  F03G4/00  to  F03G4/06
# ADDING the sequence start F03G4/00
# ADDING A PART OF the sequence F03G4/02
# ADDING A PART OF the sequence F03G4/04
# ADDING end of the sequence end F03G4/06
# FOR loop  2  7/04
# 711 2 Adding a single code  F03G7/04
# PARTS:  ['F24T', '10/00-50/00'] 2
# PROCESSING the parts  ['F24T', '10/00-50/00'] 2
# FOR loop  0 F24T
# 712 0 Adding a single code  F24TF24T
# FOR loop  1 10/00-50/00
# 712 1 ** This is a sequence from  F24T10/00  to  F24T50/00
# ADDING the sequence start F24T10/00
# ADDING A PART OF the sequence F24T10/10
# ADDING A PART OF the sequence F24T10/13
# ADDING A PART OF the sequence F24T10/15
# ADDING A PART OF the sequence F24T10/17
# ADDING A PART OF the sequence F24T10/20
# ADDING A PART OF the sequence F24T10/30
# ADDING A PART OF the sequence F24T10/40
# ADDING end of the sequence end F24T50/00
# PARTS:  ['F24V', '30/00-50/00'] 2
# PROCESSING the parts  ['F24V', '30/00-50/00'] 2
# FOR loop  0 F24V
# 722 0 Adding a single code  F24VF24V
# FOR loop  1 30/00-50/00
# 722 1 ** This is a sequence from  F24V30/00  to  F24V50/00
# WARNING no codes found for the given sequence
# PARTS:  ['F24D', '11/02'] 2
# PROCESSING the parts  ['F24D', '11/02'] 2
# FOR loop  0 F24D
# 723 0 Adding a single code  F24DF24D
# FOR loop  1 11/02
# 724 1 Adding a single code  F24D11/02
# PARTS:  ['F24D', '15/04'] 2
# PROCESSING the parts  ['F24D', '15/04'] 2
# FOR loop  0 F24D
# 725 0 Adding a single code  F24DF24D
# FOR loop  1 15/04
# 726 1 Adding a single code  F24D15/04
# issue with final comma 17/02,
# solved issue with final comma 17/02
# PARTS:  ['F24D', '17/02', '18/00'] 3
# PROCESSING the parts  ['F24D', '17/02', '18/00'] 3
# FOR loop  0 F24D
# 727 0 Adding a single code  F24DF24D
# FOR loop  1 17/02
# 728 1 Adding a single code  F24D17/02
# FOR loop  2 18/00
# 729 2 Adding a single code  F24D18/00
# PARTS:  ['F24H', '4/00'] 2
# PROCESSING the parts  ['F24H', '4/00'] 2
# FOR loop  0 F24H
# 730 0 Adding a single code  F24HF24H
# FOR loop  1 4/00
# 731 1 Adding a single code  F24H4/00
# PARTS:  ['F25B', '30/00'] 2
# PROCESSING the parts  ['F25B', '30/00'] 2
# FOR loop  0 F25B
# 732 0 Adding a single code  F25BF25B
# FOR loop  1 30/00
# 733 1 Adding a single code  F25B30/00
# PARTS:  ['F01K', '27/00'] 2
# PROCESSING the parts  ['F01K', '27/00'] 2
# FOR loop  0 F01K
# 734 0 Adding a single code  F01KF01K
# FOR loop  1 27/00
# 735 1 Adding a single code  F01K27/00
# PARTS:  ['F01K', '23/06-23/10'] 2
# PROCESSING the parts  ['F01K', '23/06-23/10'] 2
# FOR loop  0 F01K
# 736 0 Adding a single code  F01KF01K
# FOR loop  1 23/06-23/10
# 736 1 ** This is a sequence from  F01K23/06  to  F01K23/10
# WARNING no codes found for the given sequence
# PARTS:  ['F01N', '5/00'] 2
# PROCESSING the parts  ['F01N', '5/00'] 2
# FOR loop  0 F01N
# 737 0 Adding a single code  F01NF01N
# FOR loop  1 5/00
# 738 1 Adding a single code  F01N5/00
# PARTS:  ['F02G', '5/00-5/04'] 2
# PROCESSING the parts  ['F02G', '5/00-5/04'] 2
# FOR loop  0 F02G
# 739 0 Adding a single code  F02GF02G
# FOR loop  1 5/00-5/04
# 739 1 ** This is a sequence from  F02G5/00  to  F02G5/04
# ADDING the sequence start F02G5/00
# ADDING A PART OF the sequence F02G5/02
# ADDING end of the sequence end F02G5/04
# PARTS:  ['F25B', '27/02'] 2
# PROCESSING the parts  ['F25B', '27/02'] 2
# FOR loop  0 F25B
# 743 0 Adding a single code  F25BF25B
# FOR loop  1 27/02
# 744 1 Adding a single code  F25B27/02
# PARTS:  ['F01K', '17/00, 23/04'] 2
# PROCESSING the parts  ['F01K', '17/00', ' 23/04'] 3
# FOR loop  0 F01K
# 745 0 Adding a single code  F01KF01K
# FOR loop  1 17/00
# 746 1 Adding a single code  F01K17/00
# FOR loop  2  23/04
# 747 2 Adding a single code  F01K23/04
# PARTS:  ['F02C', '6/18'] 2
# PROCESSING the parts  ['F02C', '6/18'] 2
# FOR loop  0 F02C
# 748 0 Adding a single code  F02CF02C
# FOR loop  1 6/18
# 749 1 Adding a single code  F02C6/18
# PARTS:  ['F25B', '27/02'] 2
# PROCESSING the parts  ['F25B', '27/02'] 2
# FOR loop  0 F25B
# 750 0 Adding a single code  F25BF25B
# FOR loop  1 27/02
# 751 1 Adding a single code  F25B27/02
# PARTS:  ['C02F', '1/16'] 2
# PROCESSING the parts  ['C02F', '1/16'] 2
# FOR loop  0 C02F
# 752 0 Adding a single code  C02FC02F
# FOR loop  1 1/16
# 753 1 Adding a single code  C02F1/16
# PARTS:  ['D21F', '5/20'] 2
# PROCESSING the parts  ['D21F', '5/20'] 2
# FOR loop  0 D21F
# 754 0 Adding a single code  D21FD21F
# FOR loop  1 5/20
# 755 1 Adding a single code  D21F5/20
# PARTS:  ['F22B', '1/02'] 2
# PROCESSING the parts  ['F22B', '1/02'] 2
# FOR loop  0 F22B
# 756 0 Adding a single code  F22BF22B
# FOR loop  1 1/02
# 757 1 Adding a single code  F22B1/02
# PARTS:  ['F23G', '5/46'] 2
# PROCESSING the parts  ['F23G', '5/46'] 2
# FOR loop  0 F23G
# 758 0 Adding a single code  F23GF23G
# FOR loop  1 5/46
# 759 1 Adding a single code  F23G5/46
# PARTS:  ['F24F', '12/00'] 2
# PROCESSING the parts  ['F24F', '12/00'] 2
# FOR loop  0 F24F
# 760 0 Adding a single code  F24FF24F
# FOR loop  1 12/00
# 761 1 Adding a single code  F24F12/00
# PARTS:  ['F27D', '17/00'] 2
# PROCESSING the parts  ['F27D', '17/00'] 2
# FOR loop  0 F27D
# 762 0 Adding a single code  F27DF27D
# FOR loop  1 17/00
# 763 1 Adding a single code  F27D17/00
# PARTS:  ['F28D', '17/00-20/00'] 2
# PROCESSING the parts  ['F28D', '17/00-20/00'] 2
# FOR loop  0 F28D
# 764 0 Adding a single code  F28DF28D
# FOR loop  1 17/00-20/00
# 764 1 ** This is a sequence from  F28D17/00  to  F28D20/00
# ADDING the sequence start F28D17/00
# ADDING A PART OF the sequence F28D17/02
# ADDING A PART OF the sequence F28D17/04
# ADDING A PART OF the sequence F28D19/00
# ADDING A PART OF the sequence F28D19/02
# ADDING A PART OF the sequence F28D19/04
# ADDING end of the sequence end F28D20/00
# PARTS:  ['C10J', '3/86'] 2
# PROCESSING the parts  ['C10J', '3/86'] 2
# FOR loop  0 C10J
# 772 0 Adding a single code  C10JC10J
# FOR loop  1 3/86
# 773 1 Adding a single code  C10J3/86
# PARTS:  ['F03G', '5/00-5/08'] 2
# PROCESSING the parts  ['F03G', '5/00-5/08'] 2
# FOR loop  0 F03G
# 774 0 Adding a single code  F03GF03G
# FOR loop  1 5/00-5/08
# 774 1 ** This is a sequence from  F03G5/00  to  F03G5/08
# ADDING the sequence start F03G5/00
# ADDING A PART OF the sequence F03G5/02
# ADDING A PART OF the sequence F03G5/04
# ADDING A PART OF the sequence F03G5/06
# ADDING end of the sequence end F03G5/08
# PARTS:  ['B60K', '6/00, 6/20'] 2
# PROCESSING the parts  ['B60K', '6/00', ' 6/20'] 3
# FOR loop  0 B60K
# 780 0 Adding a single code  B60KB60K
# FOR loop  1 6/00
# 781 1 Adding a single code  B60K6/00
# FOR loop  2  6/20
# 782 2 Adding a single code  B60K6/20
# PARTS:  ['B60W', '20/00'] 2
# PROCESSING the parts  ['B60W', '20/00'] 2
# FOR loop  0 B60W
# 783 0 Adding a single code  B60WB60W
# FOR loop  1 20/00
# 784 1 Adding a single code  B60W20/00
# PARTS:  ['F16H', '3/00-3/78, 48/00-48/30'] 2
# PROCESSING the parts  ['F16H', '3/00-3/78', ' 48/00-48/30'] 3
# FOR loop  0 F16H
# 785 0 Adding a single code  F16HF16H
# FOR loop  1 3/00-3/78
# 785 1 ** This is a sequence from  F16H3/00  to  F16H3/78
# ADDING the sequence start F16H3/00
# ADDING A PART OF the sequence F16H3/02
# ADDING A PART OF the sequence F16H3/04
# ADDING A PART OF the sequence F16H3/06
# ADDING A PART OF the sequence F16H3/08
# ADDING A PART OF the sequence F16H3/083
# ADDING A PART OF the sequence F16H3/085
# ADDING A PART OF the sequence F16H3/087
# ...
# ADDING A PART OF the sequence F01N3/037
# ADDING A PART OF the sequence F01N3/26
# ADDING A PART OF the sequence H01L33/04
# ADDING A PART OF the sequence H01L33/42
# ADDING A PART OF the sequence H01M10/40
# ADDING A PART OF the sequence A01N29/04
# ADDING A PART OF the sequence A01N31/08
# ADDING A PART OF the sequence A01N31/10
# ADDING A PART OF the sequence A01N37/36
# ADDING A PART OF the sequence A01N37/48
# ADDING A PART OF the sequence A01N43/12
# ADDING A PART OF the sequence A01N43/72
# ADDING A PART OF the sequence A01N43/836
# ADDING A PART OF the sequence A01N47/26
# ADDING A PART OF the sequence A01N53/14
# ADDING A PART OF the sequence A01N59/10
# ADDING A PART OF the sequence A01N59/24
# ADDING A PART OF the sequence A01N61/00
# ADDING A PART OF the sequence A01N63/32
# ADDING A PART OF the sequence A01N63/34
# ADDING A PART OF the sequence B01D45/12
# ADDING A PART OF the sequence B01D46/40
# ADDING A PART OF the sequence B01D46/48
# ADDING A PART OF the sequence B01D46/54
# ADDING A PART OF the sequence B01D53/14
# ADDING A PART OF the sequence B01D53/56
# ADDING A PART OF the sequence B01D53/96
# ADDING A PART OF the sequence C04B7/04
# ADDING A PART OF the sequence C04B7/24
# ADDING A PART OF the sequence C04B18/06
# ADDING A PART OF the sequence C08J11/22
# ADDING A PART OF the sequence C08J11/28
# ADDING A PART OF the sequence E04B1/20
# ADDING A PART OF the sequence E04B1/36
# ADDING A PART OF the sequence E04C2/284
# ADDING A PART OF the sequence F01N3/031
# ADDING A PART OF the sequence H01L33/40
# ADDING A PART OF the sequence H01L33/58
# ADDING A PART OF the sequence A01N25/10
# ADDING A PART OF the sequence A01N33/18
# ADDING A PART OF the sequence A01N33/20
# ADDING A PART OF the sequence A01N35/06
# ADDING A PART OF the sequence A01N39/02
# ADDING A PART OF the sequence A01N41/06
# ADDING A PART OF the sequence A01N41/08
# ADDING A PART OF the sequence A01N43/38
# ADDING A PART OF the sequence A01N43/42
# ADDING A PART OF the sequence A01N43/86
# ADDING A PART OF the sequence A01N47/18
# ADDING A PART OF the sequence A01N47/38
# ADDING A PART OF the sequence A01N53/12
# ADDING A PART OF the sequence A01N57/10
# ADDING A PART OF the sequence A01N57/12
# ADDING A PART OF the sequence A01N59/04
# ADDING A PART OF the sequence A01N63/20
# ADDING A PART OF the sequence B01D46/30
# ADDING A PART OF the sequence B01D46/44
# ADDING A PART OF the sequence B01D47/18
# ADDING A PART OF the sequence B01D53/00
# ADDING A PART OF the sequence B01D53/02
# ADDING A PART OF the sequence B01D53/52
# ADDING A PART OF the sequence B01D53/73
# ADDING A PART OF the sequence C04B7/06
# ADDING A PART OF the sequence C04B7/147
# ADDING A PART OF the sequence C04B7/26
# ADDING A PART OF the sequence C04B7/38
# ADDING A PART OF the sequence C08J11/04
# ADDING A PART OF the sequence C08J11/24
# ADDING A PART OF the sequence D01F13/02
# ADDING A PART OF the sequence E04B1/38
# ADDING A PART OF the sequence E04B1/68
# ADDING A PART OF the sequence E04B1/682
# ADDING A PART OF the sequence F01N3/021
# ADDING A PART OF the sequence H01L33/00
# ADDING A PART OF the sequence H01L33/26
# ADDING A PART OF the sequence H01L33/44
# ADDING A PART OF the sequence H01L33/60
# ADDING A PART OF the sequence A01N29/06
# ADDING A PART OF the sequence A01N29/08
# ADDING A PART OF the sequence A01N31/12
# ADDING A PART OF the sequence A01N35/04
# ADDING A PART OF the sequence A01N37/10
# ADDING A PART OF the sequence A01N37/52
# ADDING A PART OF the sequence A01N41/10
# ADDING A PART OF the sequence A01N43/50
# ADDING A PART OF the sequence A01N43/70
# ADDING A PART OF the sequence A01N43/828
# ADDING A PART OF the sequence A01N47/22
# ADDING A PART OF the sequence A01N53/04
# ADDING A PART OF the sequence A01N63/28
# ADDING A PART OF the sequence A01N63/30
# ADDING A PART OF the sequence B01D46/06
# ADDING A PART OF the sequence B01D46/22
# ADDING A PART OF the sequence B01D46/52
# ADDING A PART OF the sequence B01D53/40
# ADDING A PART OF the sequence C04B7/00
# ADDING A PART OF the sequence C04B7/13
# ADDING A PART OF the sequence C04B7/28
# ADDING A PART OF the sequence C04B7/46
# ADDING A PART OF the sequence C04B18/08
# ADDING A PART OF the sequence C04B18/28
# ADDING A PART OF the sequence E04B1/342
# ADDING A PART OF the sequence E04B1/348
# ADDING A PART OF the sequence E04B1/49
# ADDING A PART OF the sequence E04B1/90
# ADDING A PART OF the sequence F01N3/029
# ADDING A PART OF the sequence F01N3/22
# ADDING A PART OF the sequence F01N3/36
# ADDING A PART OF the sequence H01L33/38
# ADDING A PART OF the sequence A01N25/02
# ADDING A PART OF the sequence A01N29/02
# ADDING A PART OF the sequence A01N37/08
# ADDING A PART OF the sequence A01N37/40
# ADDING A PART OF the sequence A01N43/46
# ADDING A PART OF the sequence A01N43/66
# ADDING A PART OF the sequence A01N43/90
# ADDING A PART OF the sequence A01N47/14
# ADDING A PART OF the sequence A01N53/00
# ADDING A PART OF the sequence A01N57/06
# ADDING A PART OF the sequence A01N59/00
# ADDING A PART OF the sequence A01N63/40
# ADDING A PART OF the sequence B01D46/16
# ADDING A PART OF the sequence B01D46/20
# ADDING A PART OF the sequence B01D53/38
# ADDING A PART OF the sequence B01D53/60
# ADDING A PART OF the sequence B01D53/82
# ADDING A PART OF the sequence C04B7/14
# ADDING A PART OF the sequence C04B7/43
# ADDING A PART OF the sequence E04B1/10
# ADDING A PART OF the sequence E04B1/26
# ADDING A PART OF the sequence E04B1/88
# ADDING A PART OF the sequence E04C2/292
# ADDING A PART OF the sequence F01N3/028
# ADDING A PART OF the sequence H01L33/14
# ADDING A PART OF the sequence H01L33/16
# ADDING A PART OF the sequence H01L33/30
# ADDING A PART OF the sequence A01N25/04
# ADDING A PART OF the sequence A01N25/14
# ADDING A PART OF the sequence A01N33/06
# ADDING A PART OF the sequence A01N33/14
# ADDING A PART OF the sequence A01N37/14
# ADDING A PART OF the sequence A01N37/20
# ADDING A PART OF the sequence A01N37/28
# ADDING A PART OF the sequence A01N43/32
# ADDING A PART OF the sequence A01N43/54
# ADDING A PART OF the sequence A01N43/824
# ADDING A PART OF the sequence A01N47/28
# ADDING A PART OF the sequence A01N55/08
# ADDING A PART OF the sequence A01N57/14
# ADDING A PART OF the sequence B01D53/75
# ADDING A PART OF the sequence B01D53/90
# ADDING A PART OF the sequence C04B7/12
# ADDING A PART OF the sequence C04B7/40
# ADDING A PART OF the sequence C04B7/60
# ADDING A PART OF the sequence C08J11/00
# ADDING A PART OF the sequence C08J11/02
# ADDING A PART OF the sequence E04B1/34
# ADDING A PART OF the sequence F01N3/025
# ADDING A PART OF the sequence A01N25/16
# ADDING A PART OF the sequence A01N29/10
# ADDING A PART OF the sequence A01N33/26
# ADDING A PART OF the sequence A01N35/00
# ADDING A PART OF the sequence A01N37/12
# ADDING A PART OF the sequence A01N37/42
# ADDING A PART OF the sequence A01N43/04
# ADDING A PART OF the sequence A01N43/48
# ADDING A PART OF the sequence A01N47/40
# ADDING A PART OF the sequence A01N47/42
# ADDING A PART OF the sequence A01N55/00
# ADDING A PART OF the sequence B01D45/00
# ADDING A PART OF the sequence B01D46/14
# ADDING A PART OF the sequence B01D46/28
# ADDING A PART OF the sequence B01D46/46
# ADDING A PART OF the sequence B01D47/16
# ADDING A PART OF the sequence B01D51/00
# ADDING A PART OF the sequence B01D53/12
# ADDING A PART OF the sequence B01D53/68
# ADDING A PART OF the sequence B01D53/83
# ADDING A PART OF the sequence C04B7/153
# ADDING A PART OF the sequence C04B7/19
# ADDING A PART OF the sequence C04B7/21
# ADDING A PART OF the sequence C04B18/10
# ADDING A PART OF the sequence C04B18/14
# ADDING A PART OF the sequence C22B7/02
# ADDING A PART OF the sequence E04B1/19
# ADDING A PART OF the sequence E04B1/21
# ADDING A PART OF the sequence E04B1/99
# ADDING A PART OF the sequence F01N3/05
# ADDING A PART OF the sequence F01N3/34
# ADDING A PART OF the sequence H01L33/48
# ADDING A PART OF the sequence A01N25/18
# ADDING A PART OF the sequence A01N25/28
# ADDING A PART OF the sequence A01N29/12
# ADDING A PART OF the sequence A01N43/16
# ADDING A PART OF the sequence A01N43/60
# ADDING A PART OF the sequence A01N47/34
# ADDING A PART OF the sequence A01N47/36
# ADDING A PART OF the sequence A01N49/00
# ADDING A PART OF the sequence B01D45/14
# ADDING A PART OF the sequence B01D46/12
# ADDING A PART OF the sequence B01D46/18
# ADDING A PART OF the sequence B01D47/12
# ADDING A PART OF the sequence B01D49/02
# ADDING A PART OF the sequence B01D53/08
# ADDING A PART OF the sequence B01D53/18
# ADDING A PART OF the sequence B01D53/66
# ADDING A PART OF the sequence B01D53/70
# ADDING A PART OF the sequence B01D53/84
# ADDING A PART OF the sequence B01D53/92
# ADDING A PART OF the sequence C04B7/32
# ADDING A PART OF the sequence C04B7/44
# ADDING A PART OF the sequence C04B18/18
# ADDING A PART OF the sequence C04B18/30
# ADDING A PART OF the sequence C08J11/18
# ADDING A PART OF the sequence E04C2/28
# ADDING A PART OF the sequence E04C2/288
# ADDING A PART OF the sequence F01N3/01
# ADDING A PART OF the sequence F01N3/06
# ADDING end of the sequence end F01N3/38
# PARTS:  ['B01D', '53/92'] 2
# PROCESSING the parts  ['B01D', '53/92'] 2
# FOR loop  0 B01D
# 1600 0 Adding a single code  B01DB01D
# FOR loop  1 53/92
# 1601 1 Adding a single code  B01D53/92
# PARTS:  ['F02B', '75/10'] 2
# PROCESSING the parts  ['F02B', '75/10'] 2
# FOR loop  0 F02B
# 1602 0 Adding a single code  F02BF02B
# FOR loop  1 75/10
# 1603 1 Adding a single code  F02B75/10
# PARTS:  ['C21C', '5/38'] 2
# PROCESSING the parts  ['C21C', '5/38'] 2
# FOR loop  0 C21C
# 1604 0 Adding a single code  C21CC21C
# FOR loop  1 5/38
# 1605 1 Adding a single code  C21C5/38
# PARTS:  ['C10B', '21/18'] 2
# PROCESSING the parts  ['C10B', '21/18'] 2
# FOR loop  0 C10B
# 1606 0 Adding a single code  C10BC10B
# FOR loop  1 21/18
# 1607 1 Adding a single code  C10B21/18
# PARTS:  ['F23B', '80/02'] 2
# PROCESSING the parts  ['F23B', '80/02'] 2
# FOR loop  0 F23B
# 1608 0 Adding a single code  F23BF23B
# FOR loop  1 80/02
# 1609 1 Adding a single code  F23B80/02
# PARTS:  ['F23C', '9/00'] 2
# PROCESSING the parts  ['F23C', '9/00'] 2
# FOR loop  0 F23C
# 1610 0 Adding a single code  F23CF23C
# FOR loop  1 9/00
# 1611 1 Adding a single code  F23C9/00
# PARTS:  ['F23G', '7/06'] 2
# PROCESSING the parts  ['F23G', '7/06'] 2
# FOR loop  0 F23G
# 1612 0 Adding a single code  F23GF23G
# FOR loop  1 7/06
# 1613 1 Adding a single code  F23G7/06
# PARTS:  ['F01N', '9/00'] 2
# PROCESSING the parts  ['F01N', '9/00'] 2
# FOR loop  0 F01N
# 1614 0 Adding a single code  F01NF01N
# FOR loop  1 9/00
# 1615 1 Adding a single code  F01N9/00
# PARTS:  ['B01D', '45/00-51/00'] 2
# PROCESSING the parts  ['B01D', '45/00-51/00'] 2
# FOR loop  0 B01D
# 1616 0 Adding a single code  B01DB01D
# FOR loop  1 45/00-51/00
# 1616 1 ** This is a sequence from  B01D45/00  to  B01D51/00
# ADDING the sequence start B01D45/00
# ADDING A PART OF the sequence B01D46/14
# ADDING A PART OF the sequence B01D46/28
# ADDING A PART OF the sequence B01D46/46
# ADDING A PART OF the sequence B01D47/16
# ADDING end of the sequence end B01D51/00
# PARTS:  ['B03C', '3/00'] 2
# PROCESSING the parts  ['B03C', '3/00'] 2
# FOR loop  0 B03C
# 1623 0 Adding a single code  B03CB03C
# FOR loop  1 3/00
# 1624 1 Adding a single code  B03C3/00
# PARTS:  ['C21B', '7/22'] 2
# PROCESSING the parts  ['C21B', '7/22'] 2
# FOR loop  0 C21B
# 1625 0 Adding a single code  C21BC21B
# FOR loop  1 7/22
# 1626 1 Adding a single code  C21B7/22
# PARTS:  ['C21C', '5/38'] 2
# PROCESSING the parts  ['C21C', '5/38'] 2
# FOR loop  0 C21C
# 1627 0 Adding a single code  C21CC21C
# FOR loop  1 5/38
# 1628 1 Adding a single code  C21C5/38
# PARTS:  ['F27B', '1/18'] 2
# PROCESSING the parts  ['F27B', '1/18'] 2
# FOR loop  0 F27B
# 1629 0 Adding a single code  F27BF27B
# FOR loop  1 1/18
# 1630 1 Adding a single code  F27B1/18
# PARTS:  ['F27B', '15/12'] 2
# PROCESSING the parts  ['F27B', '15/12'] 2
# FOR loop  0 F27B
# 1631 0 Adding a single code  F27BF27B
# FOR loop  1 15/12
# 1632 1 Adding a single code  F27B15/12
# PARTS:  ['C10L', '10/02, 10/06'] 2
# PROCESSING the parts  ['C10L', '10/02', ' 10/06'] 3
# FOR loop  0 C10L
# 1633 0 Adding a single code  C10LC10L
# FOR loop  1 10/02
# 1634 1 Adding a single code  C10L10/02
# FOR loop  2  10/06
# 1635 2 Adding a single code  C10L10/06
# PARTS:  ['F23J', '7/00'] 2
# PROCESSING the parts  ['F23J', '7/00'] 2
# FOR loop  0 F23J
# 1636 0 Adding a single code  F23JF23J
# FOR loop  1 7/00
# 1637 1 Adding a single code  F23J7/00
# PARTS:  ['F23J', '15/00'] 2
# PROCESSING the parts  ['F23J', '15/00'] 2
# FOR loop  0 F23J
# 1638 0 Adding a single code  F23JF23J
# FOR loop  1 15/00
# 1639 1 Adding a single code  F23J15/00
# PARTS:  ['C09K', '3/22'] 2
# PROCESSING the parts  ['C09K', '3/22'] 2
# FOR loop  0 C09K
# 1640 0 Adding a single code  C09KC09K
# FOR loop  1 3/22
# 1641 1 Adding a single code  C09K3/22
# PARTS:  ['G08B', '21/12'] 2
# PROCESSING the parts  ['G08B', '21/12'] 2
# FOR loop  0 G08B
# 1642 0 Adding a single code  G08BG08B
# FOR loop  1 21/12
# 1643 1 Adding a single code  G08B21/12
# PARTS:  ['B63J', '4/00'] 2
# PROCESSING the parts  ['B63J', '4/00'] 2
# FOR loop  0 B63J
# 1644 0 Adding a single code  B63JB63J
# FOR loop  1 4/00
# 1645 1 Adding a single code  B63J4/00
# PARTS:  ['C02F'] 1
# 1645 1 this is a short code  C02F
# PARTS:  ['C05F', '7/00'] 2
# PROCESSING the parts  ['C05F', '7/00'] 2
# FOR loop  0 C05F
# 1647 0 Adding a single code  C05FC05F
# FOR loop  1 7/00
# 1648 1 Adding a single code  C05F7/00
# PARTS:  ['C09K', '3/32'] 2
# PROCESSING the parts  ['C09K', '3/32'] 2
# FOR loop  0 C09K
# 1649 0 Adding a single code  C09KC09K
# FOR loop  1 3/32
# 1650 1 Adding a single code  C09K3/32
# PARTS:  ['B63B', '35/32'] 2
# PROCESSING the parts  ['B63B', '35/32'] 2
# FOR loop  0 B63B
# 1651 0 Adding a single code  B63BB63B
# FOR loop  1 35/32
# 1652 1 Adding a single code  B63B35/32
# PARTS:  ['E02B', '15/04'] 2
# PROCESSING the parts  ['E02B', '15/04'] 2
# FOR loop  0 E02B
# 1653 0 Adding a single code  E02BE02B
# FOR loop  1 15/04
# 1654 1 Adding a single code  E02B15/04
# PARTS:  ['E03C', '1/12'] 2
# PROCESSING the parts  ['E03C', '1/12'] 2
# FOR loop  0 E03C
# 1655 0 Adding a single code  E03CE03C
# FOR loop  1 1/12
# 1656 1 Adding a single code  E03C1/12
# PARTS:  ['C02F', '1/00, 3/00, 9/00'] 2
# PROCESSING the parts  ['C02F', '1/00', ' 3/00', ' 9/00'] 4
# FOR loop  0 C02F
# 1657 0 Adding a single code  C02FC02F
# FOR loop  1 1/00
# 1658 1 Adding a single code  C02F1/00
# FOR loop  2  3/00
# 1659 2 Adding a single code  C02F3/00
# FOR loop  3  9/00
# 1660 3 Adding a single code  C02F9/00
# PARTS:  ['E03F'] 1
# 1660 3 this is a short code  E03F
# PARTS:  ['G21C', '13/10'] 2
# PROCESSING the parts  ['G21C', '13/10'] 2
# FOR loop  0 G21C
# 1662 0 Adding a single code  G21CG21C
# FOR loop  1 13/10
# 1663 1 Adding a single code  G21C13/10
# PARTS:  ['A01G', '23/00'] 2
# PROCESSING the parts  ['A01G', '23/00'] 2
# FOR loop  0 A01G
# 1664 0 Adding a single code  A01GA01G
# FOR loop  1 23/00
# 1665 1 Adding a single code  A01G23/00
# PARTS:  ['A01G', '25/00'] 2
# PROCESSING the parts  ['A01G', '25/00'] 2
# FOR loop  0 A01G
# 1666 0 Adding a single code  A01GA01G
# FOR loop  1 25/00
# 1667 1 Adding a single code  A01G25/00
# PARTS:  ['A01N', '25/00-65/00'] 2
# PROCESSING the parts  ['A01N', '25/00-65/00'] 2
# FOR loop  0 A01N
# 1668 0 Adding a single code  A01NA01N
# FOR loop  1 25/00-65/00
# 1668 1 ** This is a sequence from  A01N25/00  to  A01N65/00
# ADDING end of the sequence end A01N65/00
# PARTS:  ['C09K', '17/00'] 2
# PROCESSING the parts  ['C09K', '17/00'] 2
# FOR loop  0 C09K
# 1670 0 Adding a single code  C09KC09K
# FOR loop  1 17/00
# 1671 1 Adding a single code  C09K17/00
# PARTS:  ['E02D', '3/00'] 2
# PROCESSING the parts  ['E02D', '3/00'] 2
# FOR loop  0 E02D
# 1672 0 Adding a single code  E02DE02D
# FOR loop  1 3/00
# 1673 1 Adding a single code  E02D3/00
# PARTS:  ['C05F'] 1
# 1673 1 this is a short code  C05F
# PARTS:  ['G06Q'] 1
# 1674 1 this is a short code  G06Q
# PARTS:  ['G08G'] 1
# 1675 1 this is a short code  G08G
# PARTS:  ['G06Q'] 1
# 1676 1 this is a short code  G06Q
# PARTS:  ['E04H', '1/00'] 2
# PROCESSING the parts  ['E04H', '1/00'] 2
# FOR loop  0 E04H
# 1678 0 Adding a single code  E04HE04H
# FOR loop  1 1/00
# 1679 1 Adding a single code  E04H1/00
# PARTS:  ['G21'] 1
# 1679 1 this is a short code  G21
# PARTS:  ['G21B'] 1
# 1680 1 this is a short code  G21B
# PARTS:  ['G21C'] 1
# 1681 1 this is a short code  G21C
# PARTS:  ['G21D'] 1
# 1682 1 this is a short code  G21D
# PARTS:  ['F02C', '1/05'] 2
# PROCESSING the parts  ['F02C', '1/05'] 2
# FOR loop  0 F02C
# 1684 0 Adding a single code  F02CF02C
# FOR loop  1 1/05
# 1685 1 Adding a single code  F02C1/05
# Done :-D
# 1136  codes found

# %%
print(codes_list)
# Out:
# ['A01G23/00', 'A01G25/00', 'A01H', 'A01N25/02', 'A01N25/04', 'A01N25/10', 'A01N25/14', 'A01N25/16', 'A01N25/18', 'A01N25/28', 'A01N29/02', 'A01N29/04', 'A01N29/06', 'A01N29/08', 'A01N29/10', 'A01N29/12', 'A01N31/06', 'A01N31/08', 'A01N31/10', 'A01N31/12', 'A01N31/16', 'A01N33/04', 'A01N33/06', 'A01N33/14', 'A01N33/18', 'A01N33/20', 'A01N33/24', 'A01N33/26', 'A01N35/00', 'A01N35/04', 'A01N35/06', 'A01N37/02', 'A01N37/08', 'A01N37/10', 'A01N37/12', 'A01N37/14', 'A01N37/20', 'A01N37/28', 'A01N37/36', 'A01N37/40', 'A01N37/42', 'A01N37/48', 'A01N37/50', 'A01N37/52', 'A01N39/02', 'A01N41/06', 'A01N41/08', 'A01N41/10', 'A01N43/04', 'A01N43/12', 'A01N43/16', 'A01N43/32', 'A01N43/38', 'A01N43/40', 'A01N43/42', 'A01N43/46', 'A01N43/48', 'A01N43/50', 'A01N43/54', 'A01N43/56', 'A01N43/58', 'A01N43/60', 'A01N43/64', 'A01N43/66', 'A01N43/70', 'A01N43/72', 'A01N43/74', 'A01N43/80', 'A01N43/824', 'A01N43/828', 'A01N43/836', 'A01N43/86', 'A01N43/88', 'A01N43/90', 'A01N47/02', 'A01N47/14', 'A01N47/18', 'A01N47/20', 'A01N47/22', 'A01N47/26', 'A01N47/28', 'A01N47/30', 'A01N47/34', 'A01N47/36', 'A01N47/38', 'A01N47/40', 'A01N47/42', 'A01N49/00', 'A01N53/00', 'A01N53/02', 'A01N53/04', 'A01N53/12', 'A01N53/14', 'A01N55/00', 'A01N55/02', 'A01N55/08', 'A01N57/06', 'A01N57/10', 'A01N57/12', 'A01N57/14', 'A01N57/16', 'A01N57/20', 'A01N57/26', 'A01N57/34', 'A01N59/00', 'A01N59/04', 'A01N59/08', 'A01N59/10', 'A01N59/12', 'A01N59/18', 'A01N59/24', 'A01N61/00', 'A01N63/04', 'A01N63/10', 'A01N63/20', 'A01N63/22', 'A01N63/28', 'A01N63/30', 'A01N63/32', 'A01N63/34', 'A01N63/40', 'A01N65/00', 'A43B1/12', 'A43B21/14', 'A61L11/00', 'A62D101/00', 'A62D3/00', 'A62D3/02', 'B01D45/00', 'B01D45/10', 'B01D45/12', 'B01D45/14', 'B01D46/00', 'B01D46/02', 'B01D46/06', 'B01D46/08', 'B01D46/12', 'B01D46/14', 'B01D46/16', 'B01D46/18', 'B01D46/20', 'B01D46/22', 'B01D46/26', 'B01D46/28', 'B01D46/30', 'B01D46/32', 'B01D46/40', 'B01D46/44', 'B01D46/46', 'B01D46/48', 'B01D46/52', 'B01D46/54', 'B01D47/04', 'B01D47/12', 'B01D47/16', 'B01D47/18', 'B01D49/00', 'B01D49/02', 'B01D51/00', 'B01D53/00', 'B01D53/02', 'B01D53/04', 'B01D53/047', 'B01D53/08', 'B01D53/12', 'B01D53/14', 'B01D53/18', 'B01D53/22', 'B01D53/24', 'B01D53/26', 'B01D53/30', 'B01D53/38', 'B01D53/40', 'B01D53/52', 'B01D53/56', 'B01D53/58', 'B01D53/60', 'B01D53/62', 'B01D53/66', 'B01D53/68', 'B01D53/70', 'B01D53/73', 'B01D53/75', 'B01D53/82', 'B01D53/83', 'B01D53/84', 'B01D53/90', 'B01D53/92', 'B01D53/94', 'B01D53/96', 'B03B9/06', 'B03C3/00', 'B09B', 'B09B3/00', 'B09C', 'B22F8/00', 'B29B17/00', 'B60K16/00', 'B60K6/00', 'B60K6/10', 'B60K6/20', 'B60K6/28', 'B60K6/30', 'B60L3/00', 'B60L50/30', 'B60L50/50', 'B60L50/51', 'B60L50/52', 'B60L50/53', 'B60L50/60', 'B60L50/61', 'B60L50/62', 'B60L50/64', 'B60L50/70', 'B60L50/71', 'B60L50/72', 'B60L50/75', 'B60L50/90', 'B60L53/00', 'B60L53/10', 'B60L53/12', 'B60L53/122', 'B60L53/124', 'B60L53/126', 'B60L53/14', 'B60L53/16', 'B60L53/18', 'B60L53/20', 'B60L53/22', 'B60L53/24', 'B60L53/30', 'B60L53/302', 'B60L53/31', 'B60L53/34', 'B60L53/35', 'B60L53/36', 'B60L53/37', 'B60L53/38', 'B60L53/39', 'B60L53/50', 'B60L53/51', 'B60L53/52', 'B60L53/53', 'B60L53/54', 'B60L53/55', 'B60L53/56', 'B60L53/57', 'B60L53/60', 'B60L53/62', 'B60L53/63', 'B60L53/64', 'B60L53/65', 'B60L53/66', 'B60L53/67', 'B60L53/68', 'B60L53/80', 'B60L55/00', 'B60L58/00', 'B60L58/10', 'B60L58/12', 'B60L58/13', 'B60L58/14', 'B60L58/15', 'B60L58/16', 'B60L58/18', 'B60L58/19', 'B60L58/20', 'B60L58/21', 'B60L58/22', 'B60L58/24', 'B60L58/25', 'B60L58/26', 'B60L58/27', 'B60L58/30', 'B60L58/31', 'B60L58/32', 'B60L58/33', 'B60L58/34', 'B60L58/40', 'B60L7/10', 'B60L7/12', 'B60L7/14', 'B60L7/16', 'B60L7/18', 'B60L7/20', 'B60L7/22', 'B60L8/00', 'B60L9/00', 'B60W10/26', 'B60W20/00', 'B61', 'B61D17/02', 'B62D35/00', 'B62D35/02', 'B62D67/00', 'B62K', 'B62M1/00', 'B62M3/00', 'B62M5/00', 'B62M6/00', 'B63B1/34', 'B63B1/36', 'B63B1/38', 'B63B1/40', 'B63B35/00', 'B63B35/32', 'B63H13/00', 'B63H16/00', 'B63H19/02', 'B63H19/04', 'B63H21/18', 'B6 ...

# %%
codes_list
# Out:
# ['A01G23/00',
#  'A01G25/00',
#  'A01H',
#  'A01N25/02',
#  'A01N25/04',
#  'A01N25/10',
#  'A01N25/14',
#  'A01N25/16',
#  'A01N25/18',
#  'A01N25/28',
#  'A01N29/02',
#  'A01N29/04',
#  'A01N29/06',
#  'A01N29/08',
#  'A01N29/10',
#  'A01N29/12',
#  'A01N31/06',
#  'A01N31/08',
#  'A01N31/10',
#  'A01N31/12',
#  'A01N31/16',
#  'A01N33/04',
#  'A01N33/06',
#  'A01N33/14',
#  'A01N33/18',
#  'A01N33/20',
#  'A01N33/24',
#  'A01N33/26',
#  'A01N35/00',
#  'A01N35/04',
#  'A01N35/06',
#  'A01N37/02',
#  'A01N37/08',
#  'A01N37/10',
#  'A01N37/12',
#  'A01N37/14',
#  'A01N37/20',
#  'A01N37/28',
#  'A01N37/36',
#  'A01N37/40',
#  'A01N37/42',
#  'A01N37/48',
#  'A01N37/50',
#  'A01N37/52',
#  'A01N39/02',
#  'A01N41/06',
#  'A01N41/08',
#  'A01N41/10',
#  'A01N43/04',
#  'A01N43/12',
#  'A01N43/16',
#  'A01N43/32',
#  'A01N43/38',
#  'A01N43/40',
#  'A01N43/42',
#  'A01N43/46',
#  'A01N43/48',
#  'A01N43/50',
#  'A01N43/54',
#  'A01N43/56',
#  'A01N43/58',
#  'A01N43/60',
#  'A01N43/64',
#  'A01N43/66',
#  'A01N43/70',
#  'A01N43/72',
#  'A01N43/74',
#  'A01N43/80',
#  'A01N43/824',
#  'A01N43/828',
#  'A01N43/836',
#  'A01N43/86',
#  'A01N43/88',
#  'A01N43/90',
#  'A01N47/02',
#  'A01N47/14',
#  'A01N47/18',
#  'A01N47/20',
#  'A01N47/22',
#  'A01N47/26',
#  'A01N47/28',
#  'A01N47/30',
#  'A01N47/34',
#  'A01N47/36',
#  'A01N47/38',
#  'A01N47/40',
#  'A01N47/42',
#  'A01N49/00',
#  'A01N53/00',
#  'A01N53/02',
#  'A01N53/04',
#  'A01N53/12',
#  'A01N53/14',
#  'A01N55/00',
#  'A01N55/02',
#  'A01N55/08',
#  'A01N57/06',
#  'A01N57/10',
#  'A01N57/12',
#  'A01N57/14',
#  'A01N57/16',
#  'A01N57/20',
#  'A01N57/26',
#  'A01N57/34',
#  'A01N59/00',
#  'A01N59/04',
#  'A01N59/08',
#  'A01N59/10',
#  'A01N59/12',
#  'A01N59/18',
#  'A01N59/24',
#  'A01N61/00',
#  'A01N63/04',
#  'A01N63/10',
#  'A01N63/20',
#  'A01N63/22',
#  'A01N63/28',
#  'A01N63/30',
#  'A01N63/32',
#  'A01N63/34',
#  'A01N63/40',
#  'A01N65/00',
#  'A43B1/12',
#  'A43B21/14',
#  'A61L11/00',
#  'A62D101/00',
#  'A62D3/00',
#  'A62D3/02',
#  'B01D45/00',
#  'B01D45/10',
#  'B01D45/12',
#  'B01D45/14',
#  'B01D46/00',
#  'B01D46/02',
#  'B01D46/06',
#  'B01D46/08',
#  'B01D46/12',
#  'B01D46/14',
#  'B01D46/16',
#  'B01D46/18',
#  'B01D46/20',
#  'B01D46/22',
#  'B01D46/26',
#  'B01D46/28',
#  'B01D46/30',
#  'B01D46/32',
#  'B01D46/40',
#  'B01D46/44',
#  'B01D46/46',
#  'B01D46/48',
#  'B01D46/52',
#  'B01D46/54',
#  'B01D47/04',
#  'B01D47/12',
#  'B01D47/16',
#  'B01D47/18',
#  'B01D49/00',
#  'B01D49/02',
#  'B01D51/00',
#  'B01D53/00',
#  'B01D53/02',
#  'B01D53/04',
#  'B01D53/047',
#  'B01D53/08',
#  'B01D53/12',
#  'B01D53/14',
#  'B01D53/18',
#  'B01D53/22',
#  'B01D53/24',
#  'B01D53/26',
#  'B01D53/30',
#  'B01D53/38',
#  'B01D53/40',
#  'B01D53/52',
#  'B01D53/56',
#  'B01D53/58',
#  'B01D53/60',
#  'B01D53/62',
#  'B01D53/66',
#  'B01D53/68',
#  'B01D53/70',
#  'B01D53/73',
#  'B01D53/75',
#  'B01D53/82',
#  'B01D53/83',
#  'B01D53/84',
#  'B01D53/90',
#  'B01D53/92',
#  'B01D53/94',
#  'B01D53/96',
#  'B03B9/06',
#  'B03C3/00',
#  'B09B',
#  'B09B3/00',
#  'B09C',
#  'B22F8/00',
#  'B29B17/00',
#  'B60K16/00',
#  'B60K6/00',
#  'B60K6/10',
#  'B60K6/20',
#  'B60K6/28',
#  'B60K6/30',
#  'B60L3/00',
#  'B60L50/30',
#  'B60L50/50',
#  'B60L50/51',
#  'B60L50/52',
#  'B60L50/53',
#  'B60L50/60',
#  'B60L50/61',
#  'B60L50/62',
#  'B60L50/64',
#  'B60L50/70',
#  'B60L50/71',
#  'B60L50/72',
#  'B60L50/75',
#  'B60L50/90',
#  'B60L53/00',
#  'B60L53/10',
#  'B60L53/12',
#  'B60L53/122',
#  'B60L53/124',
#  'B60L53/126',
#  'B60L53/14',
#  'B60L53/16',
#  'B60L53/18',
#  'B60L53/20',
#  'B60L53/22',
#  'B60L53/24',
#  'B60L53/30',
#  'B60L53/302',
#  'B60L53/31',
#  'B60L53/34',
#  'B60L53/35',
#  'B60L53/36',
#  'B60L53/37',
#  'B60L53/38',
#  'B60L53/39',
#  'B60L53/50',
#  'B60L53/51',
#  'B60L53/52',
#  'B60L53/53',
#  'B60L53/54',
#  'B60L53/55',
#  'B60L53/56',
#  'B60L53/57',
#  'B60L53/60',
#  'B60L53/62',
#  'B60L53/63',
#  'B60L53/64',
#  'B60L53/65',
#  'B60L53/66',
#  'B60L53/67',
#  'B60L53/68',
#  'B60L53/80',
#  'B60L55/00',
#  'B60L58/00',
#  'B60L58/10',
#  'B60L58/12',
#  'B60L58/13',
#  'B60L58/14',
#  'B60L58/15',
#  'B60L58/16',
#  'B60L58/18',
#  'B60L58/19',
#  'B60L58/20',
#  'B60L58/21',
#  'B60L58/22',
#  'B60L58/24',
#  'B60L58/25',
#  'B60L58/26',
#  'B60L58/27',
#  'B60L58/30',
#  'B60L58/31',
#  'B60L58/32',
#  'B60L58/33',
#  'B60L58/34',
#  'B60L58/40',
#  'B60L7/10',
#  'B60L7/12',
#  'B60L7/14',
#  'B60L7/16',
#  'B60L7/18',
#  'B60L7/20',
#  'B60L7/22',
#  'B60L8/00',
#  'B60L9/00',
#  'B60W10/26',
#  'B60W20/00',
#  'B61',
#  'B61D17/02',
#  'B62D35/00',
#  'B62D35/02',
#  'B62D67/00',
#  'B62K',
#  'B62M1/00',
#  'B62M3/00',
#  'B62M5/00',
#  'B62M6/00',
#  'B63B1/34',
#  'B63B1/36',
#  'B63B1/38',
#  'B63B1/40',
#  'B63B35/00',
#  'B63B35/32',
#  'B63H13/00',
#  'B63H16/00',
#  'B63H19/02',
#  'B63H19/04',
#  'B63H21/18',
#  'B63H9/00',
#  'B63J4/00',
#  'B64G1/44',
#  'B65F',
#  'B65G5/00',
#  'C01B32/50',
#  'C01B33/02',
#  'C02F',
#  'C02F1/00',
#  'C02F1/14',
#  'C02F1/16',
#  'C02F11/04',
#  'C02F11/14',
#  'C02F3/00',
#  'C02F3/28',
#  'C02F9/00',
#  'C04B18/04',
#  'C04B18/06',
#  'C04B18/08',
#  'C04B18/10',
#  'C04B18/12',
#  'C04B18/14',
#  'C04B18/18',
#  'C04B18/28',
#  'C04B18/30',
#  'C04B7/00',
#  'C04B7/04',
#  'C04B7/06',
#  'C04B7/12',
#  'C04B7/13',
#  'C04B7/14',
#  'C04B7/147',
#  'C04B7/153',
#  'C04B7/19',
#  'C04B7/21',
#  'C04B7/24',
#  'C04B7/26',
#  'C04B7/28',
#  'C04B7/30',
#  'C04B7/32',
#  'C04B7/38',
#  'C04B7/40',
#  'C04B7/43',
#  'C04B7/44',
#  'C04B7/46',
#  'C04B7/60',
#  'C05F',
#  'C05F7/00',
#  'C07C67/00',
#  'C07C69/00',
#  'C08J11/00',
#  'C08J11/02',
#  'C08J11/04',
#  'C08J11/18',
#  'C08J11/22',
#  'C08J11/24',
#  'C08J11/28',
#  'C09K11/01',
#  'C09K17/00',
#  'C09K3/22',
#  'C09K3/32',
#  'C09K5/00',
#  'C10B21/18',
#  'C10B53/00',
#  'C10B53/02',
#  'C10G',
#  'C10G1/10',
#  'C10J',
#  'C10J3/02',
#  'C10J3/46',
#  'C10J3/86',
#  'C10L1/00',
#  'C10L1/02',
#  'C10L1/14',
#  'C10L1/182',
#  'C10L1/19',
#  'C10L10/02',
#  'C10L10/06',
#  'C10L3/00',
#  'C10L5/00',
#  'C10L5/40',
#  'C10L5/42',
#  'C10L5/44',
#  'C10L5/46',
#  'C10L5/48',
#  'C10L9/00',
#  'C11B11/00',
#  'C11B13/04',
#  'C11C3/10',
#  'C12M1/107',
#  'C12N1/13',
#  'C12N1/15',
#  'C12N1/21',
#  'C12N15/00',
#  'C12N5/10',
#  'C12N9/24',
#  'C12P5/02',
#  'C12P7/06',
#  'C12P7/08',
#  'C12P7/10',
#  'C12P7/12',
#  'C12P7/14',
#  'C12P7/649',
#  'C14C3/32',
#  'C21B3/04',
#  'C21B5/06',
#  'C21B7/22',
#  'C21C5/38',
#  'C22B19/30',
#  'C22B25/06',
#  'C22B7/02',
#  'C22B7/04',
#  'C23C14/14',
#  'C23C16/24',
#  'C25C1/00',
#  'C30B29/06',
#  'D01F13/02',
#  'D01F13/04',
#  'D01G11/00',
#  'D21B1/08',
#  'D21B1/32',
#  'D21C11/00',
#  'D21C5/02',
#  'D21F5/20',
#  'E02B15/04',
#  'E02B9/00',
#  'E02B9/02',
#  'E02B9/04',
#  'E02B9/06',
#  'E02B9/08',
#  'E02D3/00',
#  'E03C1/12',
#  'E03F',
#  'E04B1/10',
#  'E04B1/19',
#  'E04B1/20',
#  'E04B1/21',
#  'E04B1/26',
#  'E04B1/28',
#  'E04B1/34',
#  'E04B1/342',
#  'E04B1/348',
#  'E04B1/36',
#  'E04B1/38',
#  'E04B1/49',
#  'E04B1/62',
#  'E04B1/68',
#  'E04B1/682',
#  'E04B1/686',
#  'E04B1/80',
#  'E04B1/88',
#  'E04B1/90',
#  'E04B1/99',
#  'E04B2/00',
#  'E04B5/00',
#  'E04B7/00',
#  'E04B9/00',
#  'E04C1/40',
#  'E04C1/41',
#  'E04C2/24',
#  'E04C2/28',
#  'E04C2/284',
#  'E04C2/288',
#  'E04C2/292',
#  'E04C2/296',
#  'E04D1/28',
#  'E04D13/00',
#  'E04D13/16',
#  'E04D13/18',
#  'E04D3/35',
#  'E04F13/08',
#  'E04F15/18',
#  'E04H1/00',
#  'E04H12/00',
#  'E06B3/263',
#  'E21B41/00',
#  'E21B43/16',
#  'E21F17/16',
#  'F01K',
#  'F01K17/00',
#  'F01K23/04',
#  'F01K27/00',
#  'F01N3/00',
#  'F01N3/01',
#  'F01N3/02',
#  'F01N3/021',
#  'F01N3/022',
#  'F01N3/025',
#  'F01N3/027',
#  'F01N3/028',
#  'F01N3/029',
#  'F01N3/031',
#  'F01N3/032',
#  'F01N3/037',
#  'F01N3/05',
#  'F01N3/06',
#  'F01N3/22',
#  'F01N3/24',
#  'F01N3/26',
#  'F01N3/28',
#  'F01N3/34',
#  'F01N3/36',
#  'F01N3/38',
#  'F01N5/00',
#  'F01N9/00',
#  'F02B43/00',
#  'F02B75/10',
#  'F02C1/05',
#  'F02C3/28',
#  'F02C6/18',
#  'F02G5/00',
#  'F02G5/02',
#  'F02G5/04',
#  'F02M21/02',
#  'F02M27/02',
#  'F03B',
#  'F03B13/12',
#  'F03B13/14',
#  'F03B13/16',
#  'F03B13/18',
#  'F03B13/20',
#  'F03B13/22',
#  'F03B13/24',
#  'F03B13/26',
#  'F03B15/00',
#  'F03B15/02',
#  'F03B15/04',
#  'F03B15/06',
#  'F03B15/08',
#  'F03B15/10',
#  'F03B15/12',
#  'F03B15/14',
#  'F03B15/16',
#  'F03B15/18',
#  'F03B15/20',
#  'F03B15/22',
#  'F03C',
#  'F03D',
#  'F03D1/04',
#  'F03D13/00',
#  'F03D13/20',
#  'F03D9/00',
#  'F03G4/00',
#  'F03G4/02',
#  'F03G4/04',
#  'F03G4/06',
#  'F03G5/00',
#  'F03G5/02',
#  'F03G5/04',
#  'F03G5/06',
#  'F03G5/08',
#  'F03G6/00',
#  'F03G6/02',
#  'F03G6/04',
#  'F03G6/06',
#  'F03G7/04',
#  'F03G7/05',
#  'F03G7/08',
#  'F16H3/00',
#  'F16H3/02',
#  'F16H3/04',
#  'F16H3/06',
#  'F16H3/08',
#  'F16H3/083',
#  'F16H3/085',
#  'F16H3/087',
#  'F16H3/089',
#  'F16H3/091',
#  'F16H3/093',
#  'F16H3/095',
#  'F16H3/097',
#  'F16H3/10',
#  'F16H3/12',
#  'F16H3/14',
#  'F16H3/16',
#  'F16H3/18',
#  'F16H3/20',
#  'F16H3/22',
#  'F16H3/24',
#  'F16H3/26',
#  'F16H3/28',
#  'F16H3/30',
#  'F16H3/32',
#  'F16H3/34',
#  'F16H3/36',
#  'F16H3/38',
#  'F16H3/40',
#  'F16H3/42',
#  'F16H3/44',
#  'F16H3/46',
#  'F16H3/48',
#  'F16H3/50',
#  'F16H3/52',
#  'F16H3/54',
#  'F16H3/56',
#  'F16H3/58',
#  'F16H3/60',
#  'F16H3/62',
#  'F16H3/64',
#  'F16H3/66',
#  'F16H3/68',
#  'F16H3/70',
#  'F16H3/72',
#  'F16H3/74',
#  'F16H3/76',
#  'F16H3/78',
#  'F16H48/00',
#  'F16H48/02',
#  'F16H48/04',
#  'F16H48/05',
#  'F16H48/06',
#  'F16H48/08',
#  'F16H48/10',
#  'F16H48/11',
#  'F16H48/12',
#  'F16H48/14',
#  'F16H48/16',
#  'F16H48/18',
#  'F16H48/19',
#  'F16H48/20',
#  'F16H48/22',
#  'F16H48/24',
#  'F16H48/26',
#  'F16H48/27',
#  'F16H48/28',
#  'F16H48/285',
#  'F16H48/29',
#  'F16H48/295',
#  'F16H48/30',
#  'F21K99/00',
#  'F21L4/00',
#  'F21L4/02',
#  'F21S9/03',
#  'F22B1/00',
#  'F22B1/02',
#  'F23B80/02',
#  'F23B90/00',
#  'F23C9/00',
#  'F23G',
#  'F23G5/00',
#  'F23G5/027',
#  'F23G5/46',
#  'F23G7/00',
#  'F23G7/06',
#  'F23G7/10',
#  'F23J15/00',
#  'F23J7/00',
#  'F24D11/00',
#  'F24D11/02',
#  'F24D15/04',
#  'F24D17/00',
#  'F24D17/02',
#  'F24D19/00',
#  'F24D3/00',
#  'F24D5/00',
#  'F24F12/00',
#  'F24F5/00',
#  'F24H4/00',
#  'F24H7/00',
#  'F24S',
#  'F24S10/10',
#  'F24S23/00',
#  'F24S90/00',
#  'F24T',
#  'F24T10/00',
#  'F24T10/10',
#  'F24T10/13',
#  'F24T10/15',
#  'F24T10/17',
#  'F24T10/20',
#  'F24T10/30',
#  'F24T10/40',
#  'F24T50/00',
#  'F24V30/00',
#  'F25B27/00',
#  'F25B27/02',
#  'F25B30/00',
#  'F25B30/06',
#  'F25J3/02',
#  'F26B3/00',
#  'F26B3/28',
#  'F27B1/18',
#  'F27B15/12',
#  'F27D17/00',
#  'F28D17/00',
#  'F28D17/02',
#  'F28D17/04',
#  'F28D19/00',
#  'F28D19/02',
#  'F28D19/04',
#  'F28D20/00',
#  'F28D20/02',
#  'G01R',
#  'G02B7/183',
#  'G05F1/67',
#  'G06Q',
#  'G08B21/12',
#  'G08G',
#  'G21',
#  'G21B',
#  'G21C',
#  'G21C13/10',
#  'G21D',
#  'G21F9/00',
#  'H01G11/00',
#  'H01G9/20',
#  'H01J9/50',
#  'H01J9/52',
#  'H01L25/00',
#  'H01L25/03',
#  'H01L25/16',
#  'H01L25/18',
#  'H01L27/142',
#  'H01L27/30',
#  'H01L31/00',
#  'H01L31/02',
#  'H01L31/0203',
#  'H01L31/0216',
#  'H01L31/0224',
#  'H01L31/0232',
#  'H01L31/0236',
#  'H01L31/024',
#  'H01L31/0248',
#  'H01L31/0256',
#  'H01L31/0264',
#  'H01L31/0272',
#  'H01L31/028',
#  'H01L31/0288',
#  'H01L31/0296',
#  'H01L31/0304',
#  'H01L31/0312',
#  'H01L31/032',
#  'H01L31/0328',
#  'H01L31/0336',
#  'H01L31/0352',
#  'H01L31/036',
#  'H01L31/0368',
#  'H01L31/0376',
#  'H01L31/0384',
#  'H01L31/0392',
#  'H01L31/04',
#  'H01L31/041',
#  'H01L31/042',
#  'H01L31/043',
#  'H01L31/044',
#  'H01L31/0443',
#  'H01L31/0445',
#  'H01L31/045',
#  'H01L31/046',
#  'H01L31/0463',
#  'H01L31/0465',
#  'H01L31/0468',
#  'H01L31/047',
#  'H01L31/0475',
#  'H01L31/048',
#  'H01L31/049',
#  'H01L31/05',
#  'H01L31/052',
#  'H01L31/0525',
#  'H01L31/053',
#  'H01L31/054',
#  'H01L31/055',
#  'H01L31/056',
#  'H01L31/058',
#  'H01L31/06',
#  'H01L31/061',
#  'H01L31/062',
#  'H01L31/065',
#  'H01L31/068',
#  'H01L31/0687',
#  'H01L31/0693',
#  'H01L31/07',
#  'H01L31/072',
#  'H01L31/0725',
#  'H01L31/073',
#  'H01L31/0735',
#  'H01L31/074',
#  'H01L31/0745',
#  'H01L31/0747',
#  'H01L31/0749',
#  'H01L31/075',
#  'H01L31/076',
#  'H01L31/077',
#  'H01L31/078',
#  'H01L33/00',
#  'H01L33/04',
#  'H01L33/14',
#  'H01L33/16',
#  'H01L33/26',
#  'H01L33/28',
#  'H01L33/30',
#  'H01L33/38',
#  'H01L33/40',
#  'H01L33/42',
#  'H01L33/44',
#  'H01L33/48',
#  'H01L33/56',
#  'H01L33/58',
#  'H01L33/60',
#  'H01L33/64',
#  'H01L51/42',
#  'H01L51/44',
#  'H01L51/46',
#  'H01L51/48',
#  'H01L51/50',
#  'H01M10/40',
#  'H01M10/46',
#  'H01M10/54',
#  'H01M12/00',
#  'H01M12/02',
#  'H01M12/04',
#  'H01M12/06',
#  'H01M12/08',
#  'H01M14/00',
#  'H01M4/86',
#  'H01M4/88',
#  'H01M4/90',
#  'H01M4/92',
#  'H01M4/94',
#  'H01M4/96',
#  'H01M4/98',
#  'H01M6/52',
#  'H01M8/00',
#  'H01M8/008',
#  'H01M8/02',
#  'H01M8/0202',
#  'H01M8/0204',
#  'H01M8/0206',
#  'H01M8/0208',
#  'H01M8/021',
#  'H01M8/0213',
#  'H01M8/0215',
#  'H01M8/0217',
#  'H01M8/0221',
#  'H01M8/0223',
#  'H01M8/0226',
#  'H01M8/0228',
#  'H01M8/023',
#  'H01M8/0232',
#  'H01M8/0234',
#  'H01M8/0236',
#  'H01M8/0239',
#  'H01M8/0241',
#  'H01M8/0243',
#  'H01M8/0245',
#  'H01M8/0247',
#  'H01M8/025',
#  'H01M8/0252',
#  'H01M8/0254',
#  'H01M8/0256',
#  'H01M8/0258',
#  'H01M8/026',
#  'H01M8/0263',
#  'H01M8/0265',
#  'H01M8/0267',
#  'H01M8/0271',
#  'H01M8/0273',
#  'H01M8/0276',
#  'H01M8/028',
#  'H01M8/0282',
#  'H01M8/0284',
#  'H01M8/0286',
#  'H01M8/0289',
#  'H01M8/0293',
#  'H01M8/0295',
#  'H01M8/0297',
#  'H01M8/04',
#  'H01M8/04007',
#  'H01M8/04014',
#  'H01M8/04029',
#  'H01M8/04044',
#  'H01M8/04082',
#  'H01M8/04089',
#  'H01M8/04111',
#  'H01M8/04119',
#  'H01M8/04186',
#  'H01M8/04223',
#  'H01M8/04225',
#  'H01M8/04228',
#  'H01M8/04276',
#  'H01M8/04291',
#  'H01M8/04298',
#  'H01M8/043',
#  'H01M8/04302',
#  'H01M8/04303',
#  'H01M8/04313',
#  'H01M8/0432',
#  'H01M8/0438',
#  'H01M8/0444',
#  'H01M8/04492',
#  'H01M8/04537',
#  'H01M8/04664',
#  'H01M8/04694',
#  'H01M8/04701',
#  'H01M8/04746',
#  'H01M8/04791',
#  'H01M8/04828',
#  'H01M8/04858',
#  'H01M8/04955',
#  'H01M8/04992',
#  'H01M8/06',
#  'H01M8/0606',
#  'H01M8/0612',
#  'H01M8/0637',
#  'H01M8/065',
#  'H01M8/0656',
#  'H01M8/0662',
#  'H01M8/0668',
#  'H01M8/08',
#  'H01M8/083',
#  'H01M8/086',
#  'H01M8/10',
#  'H01M8/1004',
#  'H01M8/1006',
#  'H01M8/1007',
#  'H01M8/1009',
#  'H01M8/1011',
#  'H01M8/1016',
#  'H01M8/1018',
#  'H01M8/102',
#  'H01M8/1023',
#  'H01M8/1025',
#  'H01M8/1027',
#  'H01M8/103',
#  'H01M8/1032',
#  'H01M8/1034',
#  'H01M8/1037',
#  'H01M8/1039',
#  'H01M8/1041',
#  'H01M8/1044',
#  'H01M8/1046',
#  'H01M8/1048',
#  'H01M8/1051',
#  'H01M8/1053',
#  'H01M8/1058',
#  'H01M8/106',
#  'H01M8/1062',
#  'H01M8/1065',
#  'H01M8/1067',
#  'H01M8/1069',
#  'H01M8/1072',
#  'H01M8/1081',
#  'H01M8/1086',
#  'H01M8/1088',
#  'H01M8/1097',
#  'H01M8/12',
#  'H01M8/1213',
#  'H01M8/122',
#  'H01M8/1226',
#  'H01M8/1231',
#  'H01M8/1233',
#  'H01M8/124',
#  'H01M8/1246',
#  'H01M8/1253',
#  'H01M8/126',
#  'H01M8/1286',
#  'H01M8/14',
#  'H01M8/16',
#  'H01M8/18',
#  'H01M8/20',
#  'H01M8/22',
#  'H01M8/24',
#  'H02J',
#  'H02J15/00',
#  'H02J3/28',
#  'H02J7/00',
#  'H02J7/35',
#  'H02J9/00',
#  'H02K29/08',
#  'H02K49/10',
#  'H02K7/18',
#  'H02N10/00',
#  'H02S',
#  'H02S10/00',
#  'H02S40/44',
#  'H05B33/00']

# %% [markdown]
# # write the results to a CSV file

# %%
pd.DataFrame(codes_list).to_csv("GreenCodes.csv", index=False, header=False)
