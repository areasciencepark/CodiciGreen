# %% [markdown]
# # Make a full list of Green codes

# %% [markdown]
# ## part 1: data exploration

# %%
import pandas as pd 
import re

# %%
# reading data and selecting only the column we are interested in
raw_data = pd.read_excel("../2IPCGreenInventoryList_2022WIPO.xlsx", dtype=str)
raw_data = raw_data[[ "IPC"]]
raw_data.dropna(inplace=True)
raw_data.head(20)
# Out:
#                                    IPC
# 2                 C10L 5/00, 5/40-5/48
# 3                           C10B 53/02
# 4                      C10L 5/40, 9/00
# 5                C10L 1/00, 1/02, 1/14
# 6                      C10L 1/02, 1/19
# 7                    C07C 67/00, 69/00
# 8                                 C10G
# 9                      C10L 1/02, 1/19
# 10                           C11C 3/10
# 11                          C12P 7/649
# 12                    C10L 1/02, 1/182
# 13                           C12N 9/24
# 14                      C12P 7/06-7/14
# 15                    C02F 3/28, 11/04
# 16                           C10L 3/00
# 17                          C12M 1/107
# 18                           C12P 5/02
# 19  C12N 1/13, 1/15, 1/21, 5/10, 15/00
# 20                                A01H
# 21                           C10L 3/00

# %% [markdown]
# ## try a generic for loop to scan the dataframe and identify relevant separators
#
# "," is the separator for lists of codes
# "-" is the separator for sequences
#
# scan the dataframe and add individual results in a codes_list

# %%
codes_list = []
dash = "-"
i=0
for index, row in raw_data.iterrows():
    
    first_part  = row['IPC'].split(" ")[0]
    if len(row['IPC']) <= 4:
        full_code = first_part
        print(i,j, full_code)
        i+=1
        codes_list.append(full_code)
    else:
        second_part = row['IPC'].split(" ")[1]
        other_parts = second_part.split(",")
        for j in range(0,len(other_parts)):
            this_part = re.sub("\s","",other_parts[j]) #remove whitespaces
            full_code = first_part + this_part
            if "-" in other_parts[j]:
                sequence_start = first_part + this_part.split("-")[0]
                sequence_end   = first_part + this_part.split("-")[1]
                print(i,j, "this is a sequence from ", sequence_start, " to " , sequence_end)
                # ADD here: scan the full list of codes and add everything from sequence_start to sequence_end
                i+=1
                codes_list.append(full_code)
                #########################################
            else:
                print(i,j, full_code)
                i+=1
                codes_list.append(full_code)
# Out:
# 0 0 C10L5/00
# 1 1 this is a sequence from  C10L5/40  to  C10L5/48
# 2 0 C10B53/02
# 3 0 C10L5/40
# 4 1 C10L9/00
# 5 0 C10L1/00
# 6 1 C10L1/02
# 7 2 C10L1/14
# 8 0 C10L1/02
# 9 1 C10L1/19
# 10 0 C07C67/00
# 11 1 C07C69/00
# 12 1 C10G
# 13 0 C10L1/02
# 14 1 C10L1/19
# 15 0 C11C3/10
# 16 0 C12P7/649
# 17 0 C10L1/02
# 18 1 C10L1/182
# 19 0 C12N9/24
# 20 0 this is a sequence from  C12P7/06  to  C12P7/14
# 21 0 C02F3/28
# 22 1 C02F11/04
# 23 0 C10L3/00
# 24 0 C12M1/107
# 25 0 C12P5/02
# 26 0 C12N1/13
# 27 1 C12N1/15
# 28 2 C12N1/21
# 29 3 C12N5/10
# 30 4 C12N15/00
# 31 4 A01H
# 32 0 C10L3/00
# 33 0 F02C3/28
# 34 0 this is a sequence from  H01M4/86  to  H01M4/98
# 35 1 this is a sequence from  H01M8/00  to  H01M8/24
# 36 2 this is a sequence from  H01M12/00  to  H01M12/08
# 37 0 this is a sequence from  H01M4/86  to  H01M4/98
# 38 0 this is a sequence from  H01M4/86  to  H01M4/98
# 39 0 this is a sequence from  H01M8/00  to  H01M8/24
# 40 1 H01M
# 41 0 this is a sequence from  H01M12/00  to  H01M12/08
# 42 0 C10B53/00
# 43 0 C10J
# 44 0 C10L5/00
# 45 0 C10L5/42
# 46 1 C10L5/44
# 47 0 F23G7/00
# 48 1 F23G7/10
# 49 0 C10J3/02
# 50 1 C10J3/46
# 51 0 F23B90/00
# 52 0 F23G5/027
# 53 0 B09B3/00
# 54 0 F23G7/00
# 55 0 C10L5/48
# 56 0 F23G5/00
# 57 1 F23G7/00
# 58 0 C21B5/06
# 59 0 D21C11/00
# 60 0 A62D3/02
# 61 0 C02F11/04
# 62 1 C02F11/14
# 63 0 F23G7/00
# 64 1 F23G7/10
# 65 0 B09B3/00
# 66 0 F23G5/00
# 67 0 B09B
# 68 0 B01D53/02
# 69 1 B01D53/04
# 70 2 B01D53/047
# 71 3 B01D53/14
# 72 4 B01D53/22
# 73 5 B01D53/24
# 74 0 C10L5/46
# 75 0 F23G5/00
# 76 0 this is a sequence from  E02B9/00  to  E02B9/06
# 77 0 E02B9/08
# 78 0 F03B
# 79 0 F03C
# 80 0 this is a sequence from  F03B13/12  to  F03B13/26
# 81 0 this is a sequence from  F03B15/00  to  F03B15/22
# 82 0 B63H19/02
# 83 1 B63H19/04
# 84 0 F03G7/05
# 85 0 F03D
# 86 0 H02K7/18
# 87 0 B63B35/00
# 88 0 E04H12/00
# 89 0 F03D13/00
# 90 0 B60K16/00
# 91 0 B60L8/00
# 92 0 B63H13/00
# 93 0 F24S
# 94 0 H02S
# 95 0 H01L27/142
# 96 1 this is a sequence from  H01L31/00  to  H01L31/078
# 97 0 H01G9/20
# 98 0 H02S10/00
# 99 0 H01L27/30
# 100 1 this is a sequence from  H01L51/42  to  H01L51/48
# 101 0 H01L25/00
# 102 1 H01L25/03
# 103 2 H01L25/16
# 104 3 H01L25/18
# 105 4 H01L31/042
# 106 0 C01B33/02
# 107 0 C23C14/14
# 108 1 C23C16/24
# 109 0 C30B29/06
# 110 0 G05F1/67
# 111 0 F21L4/00
# 112 0 F21S9/03
# 113 0 H02J7/35
# 114 0 H01G9/20
# 115 0 H01M14/00
# 116 0 F24S
# 117 0 F24D17/00
# 118 1 F24D
# 119 0 F24D3/00
# 120 1 F24D5/00
# 121 2 F24D11/00
# 122 3 F24D19/00
# 123 0 F24S90/00
# 124 0 F03D1/04
# 125 1 F03D9/00
# 126 2 F03D13/20
# 127 0 F03G6/00
# 128 0 C02F1/14
# 129 0 F02C1/05
# 130 0 H01L31/0525
# 131 0 H02S40/44
# 132 0 B60K16/00
# 133 0 B60L8/00
# 134 0 this is a sequence from  F03G6/00  to  F03G6/06
# 135 0 E04D13/00
# 136 1 E04D13/18
# 137 0 F22B1/00
# 138 0 F24V30/00
# 139 0 F25B27/00
# 140 0 F26B3/00
# 141 1 F26B3/28
# 142 0 F24S23/00
# 143 0 G02B7/183
# 144 0 F24S10/10
# 145 0 F24T
# 146 0 F01K
# 147 0 F24F5/00
# 148 0 this is a sequence from  F24T10/00  to  F24T50/00
# 149 0 H02N10/00
# 150 0 F25B30/06
# 151 0 this is a sequence from  F03G4/00  to  F03G4/06
# 152 1 F03G7/04
# 153 0 this is a sequence from  F24T10/00  to  F24T50/00
# 154 0 this is a sequence from  F24V30/00  to  F24V50/00
# 155 0 F24D11/02
# 156 0 F24D15/04
# 157 0 F24D17/02
# 158 1 F24D
# 159 0 F24H4/00
# 160 0 F25B30/00
# 161 0 F01K27/00
# 162 0 this is a sequence from  F01K23/06  to  F01K23/10
# 163 0 F01N5/00
# 164 0 this is a sequence from  F02G5/00  to  F02G5/04
# 165 0 F25B27/02
# 166 0 F01K17/00
# 167 1 F01K23/04
# 168 0 F02C6/18
# 169 0 F25B27/02
# 170 0 C02F1/16
# 171 0 D21F5/20
# 172 0 F22B1/02
# 173 0 F23G5/46
# 174 0 F24F12/00
# 175 0 F27D17/00
# 176 0 this is a sequence from  F28D17/00  to  F28D20/00
# 177 0 C10J3/86
# 178 0 this is a sequence from  F03G5/00  to  F03G5/08
# 179 0 B60K6/00
# 180 1 B60K6/20
# 181 0 B60W20/00
# 182 0 this is a sequence from  F16H3/00  to  F16H3/78
# 183 1 this is a sequence from  F16H48/00  to  F16H48/30
# 184 0 H02K29/08
# 185 0 H02K49/10
# 186 0 this is a sequence from  B60L7/10  to  B60L7/22
# 187 0 B60L8/00
# 188 0 B60L9/00
# 189 0 this is a sequence from  B60L50/50  to  B60L58/40
# 190 0 F02B43/00
# 191 0 F02M21/02
# 192 1 F02M27/02
# 193 0 B60K16/00
# 194 0 H02J7/00
# 195 0 B62D35/00
# 196 1 B62D35/02
# 197 0 this is a sequence from  B63B1/34  to  B63B1/40
# 198 0 B62K
# 199 0 B62M1/00
# 200 1 B62M3/00
# 201 2 B62M5/00
# 202 3 B62M6/00
# 203 3 B61
# 204 0 B61D17/02
# 205 0 B63H9/00
# 206 0 B63H13/00
# 207 0 B63H19/02
# 208 1 B63H19/04
# 209 0 B63H16/00
# 210 0 B63H21/18
# 211 0 B64G1/44
# 212 0 B60K6/28
# 213 0 B60W10/26
# 214 0 this is a sequence from  H01M10/44  to  H01M10/46
# 215 0 H01G11/00
# 216 0 H02J3/28
# 217 1 H02J7/00
# 218 2 H02J15/00
# 219 2 H02J
# 220 0 H02J9/00
# 221 0 B60L3/00
# 222 0 G01R
# 223 0 C09K5/00
# 224 0 F24H7/00
# 225 0 F28D20/00
# 226 1 F28D20/02
# 227 0 F21K99/00
# 228 0 F21L4/02
# 229 0 this is a sequence from  H01L33/00  to  H01L33/64
# 230 1 H01L51/50
# 231 0 H05B33/00
# 232 0 E04B1/62
# 233 1 this is a sequence from  E04B1/74  to  E04B1/80
# 234 2 E04B1/88
# 235 3 E04B1/90
# 236 0 E04C1/40
# 237 1 E04C1/41
# 238 2 this is a sequence from  E04C2/284  to  E04C2/296
# 239 0 E06B3/263
# 240 0 E04B2/00
# 241 0 E04F13/08
# 242 0 E04B5/00
# 243 0 E04F15/18
# 244 0 E04B7/00
# 245 0 E04D1/28
# 246 1 E04D3/35
# 247 2 E04D13/16
# 248 0 E04B9/00
# 249 0 E04F13/08
# 250 0 F03G7/08
# 251 0 B60K6/10
# 252 1 B60K6/30
# 253 0 B60L50/30
# 254 0 B09B
# 255 0 B65F
# 256 0 A61L11/00
# 257 0 A62D3/00
# 258 1 A62D101/00
# 259 0 G21F9/00
# 260 0 B03B9/06
# 261 0 B09C
# 262 0 D21B1/08
# 263 1 D21B1/32
# 264 1 F23G
# 265 0 A43B1/12
# 266 1 A43B21/14
# 267 0 B22F8/00
# 268 0 this is a sequence from  C04B7/24  to  C04B7/30
# 269 0 this is a sequence from  C04B18/04  to  C04B18/10
# 270 0 C05F
# 271 0 this is a sequence from  C08J11/00  to  C08J11/28
# 272 0 C09K11/01
# 273 0 C11B11/00
# 274 1 this is a sequence from  C11B13/00  to  C11B13/04
# 275 0 C14C3/32
# 276 0 C21B3/04
# 277 0 C25C1/00
# 278 0 this is a sequence from  D01F13/00  to  D01F13/04
# 279 0 B29B17/00
# 280 0 B62D67/00
# 281 0 this is a sequence from  C08J11/04  to  C08J11/28
# 282 0 C10G1/10
# 283 0 C10L5/46
# 284 1 C10L5/48
# 285 0 this is a sequence from  C22B7/00  to  C22B7/04
# 286 1 C22B19/30
# 287 2 C22B25/06
# 288 0 D01G11/00
# 289 0 D21C5/02
# 290 0 H01J9/50
# 291 1 H01J9/52
# 292 0 H01M6/52
# 293 1 H01M10/54
# 294 0 B01D53/14
# 295 1 B01D53/22
# 296 2 B01D53/62
# 297 0 B65G5/00
# 298 0 C01B32/50
# 299 0 E21B41/00
# 300 1 E21B43/16
# 301 0 E21F17/16
# 302 0 F25J3/02
# 303 0 this is a sequence from  B01D53/00  to  B01D53/96
# 304 0 this is a sequence from  F01N3/00  to  F01N3/38
# 305 0 B01D53/92
# 306 0 F02B75/10
# 307 0 C21C5/38
# 308 0 C10B21/18
# 309 0 F23B80/02
# 310 0 F23C9/00
# 311 0 F23G7/06
# 312 0 F01N9/00
# 313 0 this is a sequence from  B01D45/00  to  B01D51/00
# 314 0 B03C3/00
# 315 0 C21B7/22
# 316 0 C21C5/38
# 317 0 F27B1/18
# 318 0 F27B15/12
# 319 0 C10L10/02
# 320 1 C10L10/06
# 321 0 F23J7/00
# 322 0 F23J15/00
# 323 0 C09K3/22
# 324 0 G08B21/12
# 325 0 B63J4/00
# 326 0 C02F
# 327 0 C05F7/00
# 328 0 C09K3/32
# 329 0 B63B35/32
# 330 0 E02B15/04
# 331 0 E03C1/12
# 332 0 C02F1/00
# 333 1 C02F3/00
# 334 2 C02F9/00
# 335 2 E03F
# 336 0 G21C13/10
# 337 0 A01G23/00
# 338 0 A01G25/00
# 339 0 this is a sequence from  A01N25/00  to  A01N65/00
# 340 0 C09K17/00
# 341 0 E02D3/00
# 342 0 C05F
# 343 0 G06Q
# 344 0 G08G
# 345 0 G06Q
# 346 0 E04H1/00
# 347 0 G21
# 348 0 G21B
# 349 0 G21C
# 350 0 G21D
# 351 0 F02C1/05

# %%
other_parts
# Out:
# []
